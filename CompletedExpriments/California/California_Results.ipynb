# %%
# Record all test results to plot
# For detailed output and code, check the respective notebook 
import matplotlib.pyplot as plt

# %%
teacher_test_mse = 0.4885738492012024

linear_test_mse = 0.6185196156661631

rbf_test_mse = 0.3826728687078035

# %%
test_mse_with_distillation = [
    0.49305450916290283,
    1.3309773206710815,
    0.540638267993927,
    0.5488108396530151,
    0.6567452549934387,
    0.545138418674469,
    0.6345419883728027,
    0.6206130981445312,
    0.6360344290733337,
    1.330365777015686,
    0.6400263905525208,
    0.6292226314544678,
    1.3283190727233887,
    1.3325878381729126
]

# %%
test_mse_with_distillation_rbf = [

]

# %%
test_mse_without_distillation = [
    0.508552610874176,
    0.5170630216598511,
    0.5141555666923523,
    0.5857128500938416,
    0.6713912487030029,
    0.7736509442329407,
    0.6108978390693665,
    0.7470628619194031,
    0.698464035987854,
    0.8817212581634521,
    0.6652295589447021,
    0.5691846013069153,
    1.4004796743392944,
    1.4017314910888672
]

# %%
number_of_experiments = len(test_mse_with_distillation)
print(number_of_experiments)
# Out:
# 14

# %%
x = range(0, number_of_experiments)

plt.figure(figsize=(8,8))
plt.title('Test MSE with and without distillation') 

ax = plt.gca()
# ax.set_xlim([0, 1])
# ax.set_ylim([0, 1])


plt.plot(x, test_mse_with_distillation,'d-')
plt.plot(x, test_mse_without_distillation,'x-')
plt.axhline(y=teacher_test_mse, color='r', linestyle='--')
plt.axhline(y=linear_test_mse, color='r', linestyle='-.')
plt.axhline(y=rbf_test_mse, color='r', linestyle='-')

plt.legend(['With Distillation', 'Without Distillation', 'Teacher Model Baseline', 'Linear Regression Baseline', 'Random Forest Regressor Baseline'])

plt.xlabel('Experiment')
plt.ylabel('MSE')
# Out:
# Text(0, 0.5, 'MSE')
