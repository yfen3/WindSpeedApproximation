# %%
# Experiment 2 KD with a smaller model as student

# %%
# Split the training data into validation set and training set use a stratified k fold 
import numpy as np
from sklearn.model_selection import StratifiedKFold

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
from tensorflow.keras import datasets, layers, models, losses

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
# Knowledge distillation 
# Modified from source: https://keras.io/examples/vision/knowledge_distillation/

import Distiller

# %%
# Set up dataset
(x_train,y_train),(x_test,y_test) = datasets.mnist.load_data()
x_train.shape
# Out:
# (60000, 28, 28)

# %%
# Build the student model

def buildStudentModel():
    model = models.Sequential()
    model.add(layers.Conv2D(filters=6, kernel_size=(1,1), activation='relu', input_shape=(28, 28, 1)))
    model.add(layers.MaxPool2D(strides=2))
    model.add(layers.Conv2D(filters=12, kernel_size=(1,1), activation='relu'))
    model.add(layers.MaxPool2D(strides=2))
    model.add(layers.Flatten())
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(10, activation='softmax'))    
    
    return model

# %%
# Construct/load models

teacher_model = tf.keras.models.load_model('LeNetTeacherModel')
studnet_model = buildStudentModel()
studnet_model_without_distillation = keras.models.clone_model(studnet_model)

# Perform the stratified 10 fold cross validation
number_of_folds = 10

skf = StratifiedKFold(n_splits=number_of_folds)

# %%
# Haperparameter used in the experiment
number_of_epochs = 10

train_results_with_distillation = []
train_results_without_distillation = []

val_results_with_distillation = []
val_results_without_distillation = []

test_results_with_distillation = []
test_results_without_distillation = []

for i, (train_index, val_index) in enumerate(skf.split(x_train, y_train)):
    print(f"Fold {i}")
    
    x_train_fold = x_train[train_index]
    y_train_fold = y_train[train_index]
    
    x_val_fold = x_train[val_index]
    y_val_fold = y_train[val_index]
    
    distiller = Distiller.Distiller(student=studnet_model, teacher=teacher_model)
    distiller.compile(
        optimizer=keras.optimizers.Adam(),
        metrics=[keras.metrics.SparseCategoricalAccuracy()],
        student_loss_fn=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        distillation_loss_fn=keras.losses.KLDivergence(),
        alpha=0.1,
        temperature=10,
        #validation_data=(x_val_fold, y_val_fold)
    )
    # Distill teacher to student
    history = distiller.fit(x_train_fold, y_train_fold, epochs=number_of_epochs)
    train_results_with_distillation.append(history.history['sparse_categorical_accuracy'])
    
    score = distiller.evaluate(x_val_fold, y_val_fold, return_dict=True)
    val_results_with_distillation.append(score['sparse_categorical_accuracy'])
    
    
    # Train and evaluate the student model without distillation
    studnet_model_without_distillation.compile(
        optimizer=keras.optimizers.Adam(),
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[keras.metrics.SparseCategoricalAccuracy()],
    )

    # Train and evaluate student trained from scratch.
    history = studnet_model_without_distillation.fit(x_train_fold, y_train_fold, epochs=number_of_epochs)
    train_results_without_distillation.append(history.history['sparse_categorical_accuracy'])
    
    score = studnet_model_without_distillation.evaluate(x_val_fold, y_val_fold, return_dict=True)
    val_results_without_distillation.append(score['sparse_categorical_accuracy'])
    
# Evaluate the models onb the test data when the training is complete    
# Evaluate student on test dataset
test_results_with_distillation = distiller.evaluate(x_test, y_test, return_dict=True)
test_results_without_distillation = studnet_model_without_distillation.evaluate(x_test, y_test, return_dict=True)
# Out:
# Fold 0
# Epoch 1/10
# D:\anaconda3\envs\tf\lib\site-packages\keras\backend.py:5582: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 1688/1688 [==============================] - 17s 10ms/step - sparse_categorical_accuracy: 0.8179 - student_loss: 0.6952 - distillation_loss: 0.0140
# Epoch 2/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.8681 - student_loss: 0.3946 - distillation_loss: 0.0097
# Epoch 3/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.8801 - student_loss: 0.3571 - distillation_loss: 0.0089
# Epoch 4/10
# 1688/1688 [==============================] - 16s 9ms/step - sparse_categorical_accuracy: 0.8877 - student_loss: 0.3377 - distillation_loss: 0.0085
# Epoch 5/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.8935 - student_loss: 0.3167 - distillation_loss: 0.0080
# Epoch 6/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.8981 - student_loss: 0.3042 - distillation_loss: 0.0077
# Epoch 7/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9036 - student_loss: 0.2894 - distillation_loss: 0.0073
# Epoch 8/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9055 - student_loss: 0.2809 - distillation_loss: 0.0071
# Epoch 9/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9080 - student_loss: 0.2722 - distillation_loss: 0.0069
# Epoch 10/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9114 - student_loss: 0.2624 - distillation_loss: 0.0067
# 188/188 [==============================] - 1s 3ms/step - sparse_categorical_accuracy: 0.9005 - student_loss: 0.2943
# Epoch 1/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 1.3247 - sparse_categorical_accuracy: 0.7668
# Epoch 2/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.4259 - sparse_categorical_accuracy: 0.8640
# Epoch 3/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.3112 - sparse_categorical_accuracy: 0.9009
# Epoch 4/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.2792 - sparse_categorical_accuracy: 0.9084
# Epoch 5/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.2578 - sparse_categorical_accuracy: 0.9156
# Epoch 6/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.2410 - sparse_categorical_accuracy: 0.9212
# Epoch 7/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.2235 - sparse_categorical_accuracy: 0.9268
# Epoch 8/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.2114 - sparse_categorical_accuracy: 0.9310
# Epoch 9/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.2004 - sparse_categorical_accuracy: 0.9344
# Epoch 10/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1925 - sparse_categorical_accuracy: 0.9372
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2056 - sparse_categorical_accuracy: 0.9315
# Fold 1
# Epoch 1/10
# 1688/1688 [==============================] - 16s 9ms/step - sparse_categorical_accuracy: 0.9127 - student_loss: 0.2610 - distillation_loss: 0.0067
# Epoch 2/10
# 1688/1688 [==============================] - 16s 9ms/step - sparse_categorical_accuracy: 0.9164 - student_loss: 0.2508 - distillation_loss: 0.0064
# Epoch 3/10
# 1688/1688 [==============================] - 16s 9ms/step - sparse_categorical_accuracy: 0.9194 - student_loss: 0.2439 - distillation_loss: 0.0062
# Epoch 4/10
# 1688/1688 [==============================] - 16s 9ms/step - sparse_categorical_accuracy: 0.9185 - student_loss: 0.2387 - distillation_loss: 0.0062
# Epoch 5/10
# 1688/1688 [==============================] - 16s 9ms/step - sparse_categorical_accuracy: 0.9219 - student_loss: 0.2315 - distillation_loss: 0.0060
# Epoch 6/10
# 1688/1688 [==============================] - 16s 9ms/step - sparse_categorical_accuracy: 0.9221 - student_loss: 0.2280 - distillation_loss: 0.0059
# Epoch 7/10
# 1688/1688 [==============================] - 16s 10ms/step - sparse_categorical_accuracy: 0.9235 - student_loss: 0.2242 - distillation_loss: 0.0058
# Epoch 8/10
# 1688/1688 [==============================] - 16s 10ms/step - sparse_categorical_accuracy: 0.9257 - student_loss: 0.2199 - distillation_loss: 0.0057
# Epoch 9/10
# 1688/1688 [==============================] - 16s 10ms/step - sparse_categorical_accuracy: 0.9265 - student_loss: 0.2165 - distillation_loss: 0.0056
# Epoch 10/10
# 1688/1688 [==============================] - 16s 10ms/step - sparse_categorical_accuracy: 0.9272 - student_loss: 0.2132 - distillation_loss: 0.0056
# 188/188 [==============================] - 1s 3ms/step - sparse_categorical_accuracy: 0.9003 - student_loss: 0.2988
# Epoch 1/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1840 - sparse_categorical_accuracy: 0.9408
# Epoch 2/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1785 - sparse_categorical_accuracy: 0.9416
# Epoch 3/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1698 - sparse_categorical_accuracy: 0.9436
# Epoch 4/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1632 - sparse_categorical_accuracy: 0.9458
# Epoch 5/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1594 - sparse_categorical_accuracy: 0.9473
# Epoch 6/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1540 - sparse_categorical_accuracy: 0.9489
# Epoch 7/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1508 - sparse_categorical_accuracy: 0.9499
# Epoch 8/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1469 - sparse_categorical_accuracy: 0.9515
# Epoch 9/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1437 - sparse_categorical_accuracy: 0.9516
# Epoch 10/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1398 - sparse_categorical_accuracy: 0.9534
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2008 - sparse_categorical_accuracy: 0.9375
# Fold 2
# Epoch 1/10
# 1688/1688 [==============================] - 16s 9ms/step - sparse_categorical_accuracy: 0.9259 - student_loss: 0.2202 - distillation_loss: 0.0057
# Epoch 2/10
# 1688/1688 [==============================] - 16s 9ms/step - sparse_categorical_accuracy: 0.9281 - student_loss: 0.2124 - distillation_loss: 0.0055
# Epoch 3/10
# 1688/1688 [==============================] - 16s 9ms/step - sparse_categorical_accuracy: 0.9279 - student_loss: 0.2121 - distillation_loss: 0.0055
# Epoch 4/10
# 1688/1688 [==============================] - 16s 9ms/step - sparse_categorical_accuracy: 0.9297 - student_loss: 0.2069 - distillation_loss: 0.0054
# Epoch 5/10
# 1688/1688 [==============================] - 16s 9ms/step - sparse_categorical_accuracy: 0.9306 - student_loss: 0.2026 - distillation_loss: 0.0053
# Epoch 6/10
# 1688/1688 [==============================] - 16s 9ms/step - sparse_categorical_accuracy: 0.9323 - student_loss: 0.1996 - distillation_loss: 0.0052
# Epoch 7/10
# 1688/1688 [==============================] - 16s 9ms/step - sparse_categorical_accuracy: 0.9313 - student_loss: 0.1986 - distillation_loss: 0.0052
# Epoch 8/10
# 1688/1688 [==============================] - 16s 9ms/step - sparse_categorical_accuracy: 0.9329 - student_loss: 0.1941 - distillation_loss: 0.0051
# Epoch 9/10
# 1688/1688 [==============================] - 16s 9ms/step - sparse_categorical_accuracy: 0.9342 - student_loss: 0.1932 - distillation_loss: 0.0051
# Epoch 10/10
# 1688/1688 [==============================] - 16s 9ms/step - sparse_categorical_accuracy: 0.9347 - student_loss: 0.1912 - distillation_loss: 0.0051
# 188/188 [==============================] - 1s 3ms/step - sparse_categorical_accuracy: 0.9197 - student_loss: 0.2523
# Epoch 1/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1483 - sparse_categorical_accuracy: 0.9502
# Epoch 2/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1400 - sparse_categorical_accuracy: 0.9528
# Epoch 3/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1337 - sparse_categorical_accuracy: 0.9549
# Epoch 4/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1308 - sparse_categorical_accuracy: 0.9559
# Epoch 5/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1274 - sparse_categorical_accuracy: 0.9564
# Epoch 6/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1237 - sparse_categorical_accuracy: 0.9584
# Epoch 7/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1223 - sparse_categorical_accuracy: 0.9567
# Epoch 8/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1154 - sparse_categorical_accuracy: 0.9614
# Epoch 9/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1149 - sparse_categorical_accuracy: 0.9605
# Epoch 10/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1105 - sparse_categorical_accuracy: 0.9620
# 188/188 [==============================] - 1s 3ms/step - loss: 0.1588 - sparse_categorical_accuracy: 0.9485
# Fold 3
# Epoch 1/10
# 1688/1688 [==============================] - 16s 9ms/step - sparse_categorical_accuracy: 0.9335 - student_loss: 0.1967 - distillation_loss: 0.0051
# Epoch 2/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9345 - student_loss: 0.1921 - distillation_loss: 0.0051
# Epoch 3/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9356 - student_loss: 0.1893 - distillation_loss: 0.0050
# Epoch 4/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9361 - student_loss: 0.1856 - distillation_loss: 0.0049
# Epoch 5/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9379 - student_loss: 0.1828 - distillation_loss: 0.0048
# Epoch 6/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9382 - student_loss: 0.1813 - distillation_loss: 0.0048
# Epoch 7/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9385 - student_loss: 0.1794 - distillation_loss: 0.0048
# Epoch 8/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9394 - student_loss: 0.1777 - distillation_loss: 0.0047
# Epoch 9/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9393 - student_loss: 0.1752 - distillation_loss: 0.0047
# Epoch 10/10
# 1688/1688 [==============================] - 16s 9ms/step - sparse_categorical_accuracy: 0.9402 - student_loss: 0.1742 - distillation_loss: 0.0047
# 188/188 [==============================] - 1s 2ms/step - sparse_categorical_accuracy: 0.9237 - student_loss: 0.2290
# Epoch 1/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1168 - sparse_categorical_accuracy: 0.9608
# Epoch 2/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1112 - sparse_categorical_accuracy: 0.9621
# Epoch 3/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1077 - sparse_categorical_accuracy: 0.9628
# Epoch 4/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1071 - sparse_categorical_accuracy: 0.9632
# Epoch 5/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1024 - sparse_categorical_accuracy: 0.9648
# Epoch 6/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0988 - sparse_categorical_accuracy: 0.9655
# Epoch 7/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0949 - sparse_categorical_accuracy: 0.9674
# Epoch 8/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0907 - sparse_categorical_accuracy: 0.9684
# Epoch 9/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0852 - sparse_categorical_accuracy: 0.9710
# Epoch 10/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0824 - sparse_categorical_accuracy: 0.9716
# 188/188 [==============================] - 1s 3ms/step - loss: 0.1751 - sparse_categorical_accuracy: 0.9440
# Fold 4
# Epoch 1/10
# 1688/1688 [==============================] - 16s 9ms/step - sparse_categorical_accuracy: 0.9388 - student_loss: 0.1783 - distillation_loss: 0.0048
# Epoch 2/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9394 - student_loss: 0.1739 - distillation_loss: 0.0047
# Epoch 3/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9411 - student_loss: 0.1719 - distillation_loss: 0.0046
# Epoch 4/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9415 - student_loss: 0.1703 - distillation_loss: 0.0046
# Epoch 5/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9425 - student_loss: 0.1670 - distillation_loss: 0.0045
# Epoch 6/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9434 - student_loss: 0.1665 - distillation_loss: 0.0044
# Epoch 7/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9437 - student_loss: 0.1635 - distillation_loss: 0.0044
# Epoch 8/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9445 - student_loss: 0.1612 - distillation_loss: 0.0044
# Epoch 9/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9446 - student_loss: 0.1617 - distillation_loss: 0.0044
# Epoch 10/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9445 - student_loss: 0.1589 - distillation_loss: 0.0043
# 188/188 [==============================] - 1s 2ms/step - sparse_categorical_accuracy: 0.9303 - student_loss: 0.2047
# Epoch 1/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0872 - sparse_categorical_accuracy: 0.9704
# Epoch 2/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0779 - sparse_categorical_accuracy: 0.9723
# Epoch 3/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0758 - sparse_categorical_accuracy: 0.9743
# Epoch 4/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0749 - sparse_categorical_accuracy: 0.9734
# Epoch 5/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0715 - sparse_categorical_accuracy: 0.9747
# Epoch 6/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0682 - sparse_categorical_accuracy: 0.9771
# Epoch 7/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0662 - sparse_categorical_accuracy: 0.9772
# Epoch 8/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0648 - sparse_categorical_accuracy: 0.9776
# Epoch 9/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0638 - sparse_categorical_accuracy: 0.9777
# Epoch 10/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0620 - sparse_categorical_accuracy: 0.9788
# 188/188 [==============================] - 1s 3ms/step - loss: 0.0990 - sparse_categorical_accuracy: 0.9663
# Fold 5
# Epoch 1/10
# 1688/1688 [==============================] - 16s 9ms/step - sparse_categorical_accuracy: 0.9431 - student_loss: 0.1642 - distillation_loss: 0.0044
# Epoch 2/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9450 - student_loss: 0.1607 - distillation_loss: 0.0043
# Epoch 3/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9464 - student_loss: 0.1558 - distillation_loss: 0.0042
# Epoch 4/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9461 - student_loss: 0.1566 - distillation_loss: 0.0042
# Epoch 5/10
# 1688/1688 [==============================] - 16s 9ms/step - sparse_categorical_accuracy: 0.9470 - student_loss: 0.1541 - distillation_loss: 0.0042
# Epoch 6/10
# 1688/1688 [==============================] - 16s 9ms/step - sparse_categorical_accuracy: 0.9479 - student_loss: 0.1527 - distillation_loss: 0.0041
# Epoch 7/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9478 - student_loss: 0.1507 - distillation_loss: 0.0041
# Epoch 8/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9483 - student_loss: 0.1505 - distillation_loss: 0.0041
# Epoch 9/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9487 - student_loss: 0.1490 - distillation_loss: 0.0041
# Epoch 10/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9484 - student_loss: 0.1477 - distillation_loss: 0.0040
# 188/188 [==============================] - 1s 2ms/step - sparse_categorical_accuracy: 0.9335 - student_loss: 0.1985
# Epoch 1/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0689 - sparse_categorical_accuracy: 0.9759
# Epoch 2/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0621 - sparse_categorical_accuracy: 0.9783
# Epoch 3/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0630 - sparse_categorical_accuracy: 0.9787
# Epoch 4/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0596 - sparse_categorical_accuracy: 0.9794
# Epoch 5/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0583 - sparse_categorical_accuracy: 0.9798
# Epoch 6/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0551 - sparse_categorical_accuracy: 0.9808
# Epoch 7/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0556 - sparse_categorical_accuracy: 0.9805
# Epoch 8/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0534 - sparse_categorical_accuracy: 0.9809
# Epoch 9/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0562 - sparse_categorical_accuracy: 0.9805
# Epoch 10/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0484 - sparse_categorical_accuracy: 0.9828
# 188/188 [==============================] - 1s 2ms/step - loss: 0.0945 - sparse_categorical_accuracy: 0.9700
# Fold 6
# Epoch 1/10
# 1688/1688 [==============================] - 16s 9ms/step - sparse_categorical_accuracy: 0.9468 - student_loss: 0.1538 - distillation_loss: 0.0042
# Epoch 2/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9479 - student_loss: 0.1501 - distillation_loss: 0.0041
# Epoch 3/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9502 - student_loss: 0.1469 - distillation_loss: 0.0040
# Epoch 4/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9500 - student_loss: 0.1454 - distillation_loss: 0.0040
# Epoch 5/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9501 - student_loss: 0.1446 - distillation_loss: 0.0040
# Epoch 6/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9508 - student_loss: 0.1423 - distillation_loss: 0.0039
# Epoch 7/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9510 - student_loss: 0.1412 - distillation_loss: 0.0039
# Epoch 8/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9519 - student_loss: 0.1405 - distillation_loss: 0.0039
# Epoch 9/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9528 - student_loss: 0.1372 - distillation_loss: 0.0038
# Epoch 10/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9518 - student_loss: 0.1389 - distillation_loss: 0.0038
# 188/188 [==============================] - 1s 2ms/step - sparse_categorical_accuracy: 0.9298 - student_loss: 0.2008
# Epoch 1/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0580 - sparse_categorical_accuracy: 0.9802
# Epoch 2/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.0516 - sparse_categorical_accuracy: 0.9821
# Epoch 3/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0514 - sparse_categorical_accuracy: 0.9824
# Epoch 4/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.0485 - sparse_categorical_accuracy: 0.9828
# Epoch 5/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0499 - sparse_categorical_accuracy: 0.9824
# Epoch 6/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0454 - sparse_categorical_accuracy: 0.9838
# Epoch 7/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.0461 - sparse_categorical_accuracy: 0.9835
# Epoch 8/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.0466 - sparse_categorical_accuracy: 0.9833
# Epoch 9/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.0444 - sparse_categorical_accuracy: 0.9841
# Epoch 10/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.0446 - sparse_categorical_accuracy: 0.9840
# 188/188 [==============================] - 1s 2ms/step - loss: 0.1004 - sparse_categorical_accuracy: 0.9683
# Fold 7
# Epoch 1/10
# 1688/1688 [==============================] - 16s 9ms/step - sparse_categorical_accuracy: 0.9497 - student_loss: 0.1445 - distillation_loss: 0.0039
# Epoch 2/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9511 - student_loss: 0.1408 - distillation_loss: 0.0039
# Epoch 3/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9509 - student_loss: 0.1393 - distillation_loss: 0.0038
# Epoch 4/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9523 - student_loss: 0.1373 - distillation_loss: 0.0038
# Epoch 5/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9534 - student_loss: 0.1353 - distillation_loss: 0.0037
# Epoch 6/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9531 - student_loss: 0.1346 - distillation_loss: 0.0037
# Epoch 7/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9542 - student_loss: 0.1323 - distillation_loss: 0.0037
# Epoch 8/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9553 - student_loss: 0.1317 - distillation_loss: 0.0036
# Epoch 9/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9546 - student_loss: 0.1308 - distillation_loss: 0.0036
# Epoch 10/10
# 1688/1688 [==============================] - 15s 9ms/step - sparse_categorical_accuracy: 0.9554 - student_loss: 0.1297 - distillation_loss: 0.0036
# 188/188 [==============================] - 1s 3ms/step - sparse_categorical_accuracy: 0.9315 - student_loss: 0.1923
# Epoch 1/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0499 - sparse_categorical_accuracy: 0.9827
# Epoch 2/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0422 - sparse_categorical_accuracy: 0.9858
# Epoch 3/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0486 - sparse_categorical_accuracy: 0.9830
# Epoch 4/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0412 - sparse_categorical_accuracy: 0.9850
# Epoch 5/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0463 - sparse_categorical_accuracy: 0.9839
# Epoch 6/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0403 - sparse_categorical_accuracy: 0.9857
# Epoch 7/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0403 - sparse_categorical_accuracy: 0.9857
# Epoch 8/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0397 - sparse_categorical_accuracy: 0.9864
# Epoch 9/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0382 - sparse_categorical_accuracy: 0.9865
# Epoch 10/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0371 - sparse_categorical_accuracy: 0.9869
# 188/188 [==============================] - 1s 2ms/step - loss: 0.1021 - sparse_categorical_accuracy: 0.9670
# Fold 8
# Epoch 1/10
# 1688/1688 [==============================] - 8s 5ms/step - sparse_categorical_accuracy: 0.9524 - student_loss: 0.1366 - distillation_loss: 0.0038
# Epoch 2/10
# 1688/1688 [==============================] - 8s 5ms/step - sparse_categorical_accuracy: 0.9541 - student_loss: 0.1329 - distillation_loss: 0.0037
# Epoch 3/10
# 1688/1688 [==============================] - 8s 5ms/step - sparse_categorical_accuracy: 0.9544 - student_loss: 0.1308 - distillation_loss: 0.0036
# Epoch 4/10
# 1688/1688 [==============================] - 8s 5ms/step - sparse_categorical_accuracy: 0.9549 - student_loss: 0.1316 - distillation_loss: 0.0037
# Epoch 5/10
# 1688/1688 [==============================] - 8s 5ms/step - sparse_categorical_accuracy: 0.9550 - student_loss: 0.1283 - distillation_loss: 0.0036
# Epoch 6/10
# 1688/1688 [==============================] - 8s 5ms/step - sparse_categorical_accuracy: 0.9563 - student_loss: 0.1267 - distillation_loss: 0.0035
# Epoch 7/10
# 1688/1688 [==============================] - 8s 5ms/step - sparse_categorical_accuracy: 0.9561 - student_loss: 0.1252 - distillation_loss: 0.0035
# Epoch 8/10
# 1688/1688 [==============================] - 8s 5ms/step - sparse_categorical_accuracy: 0.9565 - student_loss: 0.1263 - distillation_loss: 0.0035
# Epoch 9/10
# 1688/1688 [==============================] - 8s 5ms/step - sparse_categorical_accuracy: 0.9566 - student_loss: 0.1250 - distillation_loss: 0.0035
# Epoch 10/10
# 1688/1688 [==============================] - 8s 5ms/step - sparse_categorical_accuracy: 0.9572 - student_loss: 0.1230 - distillation_loss: 0.0035
# 188/188 [==============================] - 1s 2ms/step - sparse_categorical_accuracy: 0.9380 - student_loss: 0.1779
# Epoch 1/10
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0446 - sparse_categorical_accuracy: 0.9850
# Epoch 2/10
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0418 - sparse_categorical_accuracy: 0.9854
# Epoch 3/10
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0420 - sparse_categorical_accuracy: 0.9857
# Epoch 4/10
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0369 - sparse_categorical_accuracy: 0.9869
# Epoch 5/10
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0393 - sparse_categorical_accuracy: 0.9863
# Epoch 6/10
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0351 - sparse_categorical_accuracy: 0.9880
# Epoch 7/10
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0423 - sparse_categorical_accuracy: 0.9858
# Epoch 8/10
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0353 - sparse_categorical_accuracy: 0.9879
# Epoch 9/10
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0341 - sparse_categorical_accuracy: 0.9878
# Epoch 10/10
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0363 - sparse_categorical_accuracy: 0.9871
# 188/188 [==============================] - 0s 2ms/step - loss: 0.0882 - sparse_categorical_accuracy: 0.9707
# Fold 9
# Epoch 1/10
# 1688/1688 [==============================] - 7s 4ms/step - sparse_categorical_accuracy: 0.9541 - student_loss: 0.1316 - distillation_loss: 0.0037
# Epoch 2/10
# 1688/1688 [==============================] - 7s 4ms/step - sparse_categorical_accuracy: 0.9556 - student_loss: 0.1269 - distillation_loss: 0.0036
# Epoch 3/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9567 - student_loss: 0.1269 - distillation_loss: 0.0035
# Epoch 4/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9579 - student_loss: 0.1254 - distillation_loss: 0.0035
# Epoch 5/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9587 - student_loss: 0.1218 - distillation_loss: 0.0034
# Epoch 6/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9563 - student_loss: 0.1232 - distillation_loss: 0.0035
# Epoch 7/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9565 - student_loss: 0.1227 - distillation_loss: 0.0035
# Epoch 8/10
# 1688/1688 [==============================] - 7s 4ms/step - sparse_categorical_accuracy: 0.9576 - student_loss: 0.1205 - distillation_loss: 0.0034
# Epoch 9/10
# 1688/1688 [==============================] - 7s 4ms/step - sparse_categorical_accuracy: 0.9588 - student_loss: 0.1193 - distillation_loss: 0.0033
# Epoch 10/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9577 - student_loss: 0.1208 - distillation_loss: 0.0034
# 188/188 [==============================] - 0s 2ms/step - sparse_categorical_accuracy: 0.9463 - student_loss: 0.1527
# Epoch 1/10
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0429 - sparse_categorical_accuracy: 0.9858
# Epoch 2/10
# 1688/1688 [==============================] - 4s 3ms/step - loss: 0.0405 - sparse_categorical_accuracy: 0.9864
# Epoch 3/10
# 1688/1688 [==============================] - 4s 3ms/step - loss: 0.0394 - sparse_categorical_accuracy: 0.9860
# Epoch 4/10
# 1688/1688 [==============================] - 4s 3ms/step - loss: 0.0345 - sparse_categorical_accuracy: 0.9878
# Epoch 5/10
# 1688/1688 [==============================] - 4s 3ms/step - loss: 0.0387 - sparse_categorical_accuracy: 0.9864
# Epoch 6/10
# 1688/1688 [==============================] - 4s 3ms/step - loss: 0.0336 - sparse_categorical_accuracy: 0.9882
# Epoch 7/10
# 1688/1688 [==============================] - 4s 3ms/step - loss: 0.0395 - sparse_categorical_accuracy: 0.9868
# Epoch 8/10
# 1688/1688 [==============================] - 4s 3ms/step - loss: 0.0326 - sparse_categorical_accuracy: 0.9890
# Epoch 9/10
# 1688/1688 [==============================] - 4s 3ms/step - loss: 0.0371 - sparse_categorical_accuracy: 0.9873
# Epoch 10/10
# 1688/1688 [==============================] - 4s 3ms/step - loss: 0.0325 - sparse_categorical_accuracy: 0.9890
# 188/188 [==============================] - 0s 2ms/step - loss: 0.0591 - sparse_categorical_accuracy: 0.9850
# 313/313 [==============================] - 1s 2ms/step - sparse_categorical_accuracy: 0.9009 - student_loss: 0.3838
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3685 - sparse_categorical_accuracy: 0.9488

# %%
fig, axs = plt.subplots(2, 1, figsize=(15,15))

# Traning and validation results
axs[0].plot(np.mean(train_results_with_distillation, 1), '-D') 
axs[0].plot(np.mean(train_results_without_distillation, 1), '-x') 
axs[0].title.set_text('Training Accuracy with and without distillation') 
axs[0].legend(['With Distillation', 'Without Distillation'])  

# Test results
axs[1].plot(val_results_with_distillation, '-D') 
axs[1].plot(val_results_without_distillation, '-x') 
axs[1].title.set_text('Validation Accuracy with and without distillation') 
axs[1].legend(['With Distillation', 'Without Distillation'])

# %%
print(f"Test accuracy with disstillation {test_results_with_distillation['sparse_categorical_accuracy']}")
print(f"Test accuracy without disstillation {test_results_without_distillation['sparse_categorical_accuracy']}")
# Out:
# Test accuracy with disstillation 0.9009000062942505
# Test accuracy without disstillation 0.9488000273704529

# %%
# # Save the model to load in future
# %mkdir Exp1Models
#%mkdir Exp1Models/Exp2

# studnet_model.save('Exp1Models/Exp2/studnet_model')
# studnet_model_without_distillation.save('Exp1Models/Exp2/studnet_model_without_distillation')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# The syntax of the command is incorrect.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Exp1Models/Exp2/studnet_model\assets
# INFO:tensorflow:Assets written to: Exp1Models/Exp2/studnet_model\assets
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Exp1Models/Exp2/studnet_model_without_distillation\assets
# INFO:tensorflow:Assets written to: Exp1Models/Exp2/studnet_model_without_distillation\assets
