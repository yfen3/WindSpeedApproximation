# %%
# Experiment 4 KD with a much smaller model as student

# %%
# Split the training data into validation set and training set use a stratified k fold 
import numpy as np
from sklearn.model_selection import StratifiedKFold

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
from tensorflow.keras import datasets, layers, models, losses

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
# Knowledge distillation 
# Modified from source: https://keras.io/examples/vision/knowledge_distillation/

import Distiller

# %%
# Set up dataset
(x_train,y_train),(x_test,y_test) = datasets.mnist.load_data()
x_train.shape
# Out:
# (60000, 28, 28)

# %%
# Build the student model

def buildStudentModel():
    model = models.Sequential()
    model.add(layers.Conv2D(filters=1, kernel_size=(5,5), activation='relu', input_shape=(28, 28, 1)))
    model.add(layers.MaxPool2D(strides=2))
    
    model.add(layers.Flatten())
    model.add(layers.Dense(32, activation='relu'))
    model.add(layers.Dense(16, activation='relu'))
    model.add(layers.Dense(10, activation='softmax'))    
    
    return model

# %%
# Construct/load models

teacher_model = tf.keras.models.load_model('LeNetTeacherModel')
studnet_model = buildStudentModel()
studnet_model_without_distillation = keras.models.clone_model(studnet_model)

# Perform the stratified 10 fold cross validation
number_of_folds = 10

skf = StratifiedKFold(n_splits=number_of_folds)

# %%
# Haperparameter used in the experiment
number_of_epochs = 10

train_results_with_distillation = []
train_results_without_distillation = []

val_results_with_distillation = []
val_results_without_distillation = []

test_results_with_distillation = []
test_results_without_distillation = []

for i, (train_index, val_index) in enumerate(skf.split(x_train, y_train)):
    print(f"Fold {i}")
    
    x_train_fold = x_train[train_index]
    y_train_fold = y_train[train_index]
    
    x_val_fold = x_train[val_index]
    y_val_fold = y_train[val_index]
    
    distiller = Distiller.Distiller(student=studnet_model, teacher=teacher_model)
    distiller.compile(
        optimizer=keras.optimizers.Adam(),
        metrics=[keras.metrics.SparseCategoricalAccuracy()],
        student_loss_fn=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        distillation_loss_fn=keras.losses.KLDivergence(),
        alpha=0.1,
        temperature=10,
        #validation_data=(x_val_fold, y_val_fold)
    )
    # Distill teacher to student
    history = distiller.fit(x_train_fold, y_train_fold, epochs=number_of_epochs)
    train_results_with_distillation.append(history.history['sparse_categorical_accuracy'])
    
    score = distiller.evaluate(x_val_fold, y_val_fold, return_dict=True)
    val_results_with_distillation.append(score['sparse_categorical_accuracy'])
    
    
    # Train and evaluate the student model without distillation
    studnet_model_without_distillation.compile(
        optimizer=keras.optimizers.Adam(),
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[keras.metrics.SparseCategoricalAccuracy()],
    )

    # Train and evaluate student trained from scratch.
    history = studnet_model_without_distillation.fit(x_train_fold, y_train_fold, epochs=number_of_epochs)
    train_results_without_distillation.append(history.history['sparse_categorical_accuracy'])
    
    score = studnet_model_without_distillation.evaluate(x_val_fold, y_val_fold, return_dict=True)
    val_results_without_distillation.append(score['sparse_categorical_accuracy'])
    
# Evaluate the models onb the test data when the training is complete    
# Evaluate student on test dataset
test_results_with_distillation = distiller.evaluate(x_test, y_test, return_dict=True)
test_results_without_distillation = studnet_model_without_distillation.evaluate(x_test, y_test, return_dict=True)
# Out:
# Fold 0
# Epoch 1/10
# D:\anaconda3\envs\tf\lib\site-packages\keras\backend.py:5582: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 1688/1688 [==============================] - 12s 4ms/step - sparse_categorical_accuracy: 0.6686 - student_loss: 1.3320 - distillation_loss: 0.0235
# Epoch 2/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9016 - student_loss: 0.3416 - distillation_loss: 0.0076
# Epoch 3/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9292 - student_loss: 0.2423 - distillation_loss: 0.0055
# Epoch 4/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9404 - student_loss: 0.1990 - distillation_loss: 0.0045
# Epoch 5/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9480 - student_loss: 0.1740 - distillation_loss: 0.0040
# Epoch 6/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9538 - student_loss: 0.1529 - distillation_loss: 0.0035
# Epoch 7/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9572 - student_loss: 0.1420 - distillation_loss: 0.0033
# Epoch 8/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9597 - student_loss: 0.1324 - distillation_loss: 0.0031
# Epoch 9/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9616 - student_loss: 0.1261 - distillation_loss: 0.0030
# Epoch 10/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9647 - student_loss: 0.1178 - distillation_loss: 0.0028
# 188/188 [==============================] - 0s 2ms/step - sparse_categorical_accuracy: 0.9555 - student_loss: 0.1487
# Epoch 1/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 3.2413 - sparse_categorical_accuracy: 0.3861
# Epoch 2/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.9856 - sparse_categorical_accuracy: 0.6614
# Epoch 3/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.6817 - sparse_categorical_accuracy: 0.7922
# Epoch 4/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.4671 - sparse_categorical_accuracy: 0.8717
# Epoch 5/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.3328 - sparse_categorical_accuracy: 0.9078
# Epoch 6/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.2612 - sparse_categorical_accuracy: 0.9259
# Epoch 7/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.2184 - sparse_categorical_accuracy: 0.9374
# Epoch 8/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.1962 - sparse_categorical_accuracy: 0.9431
# Epoch 9/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.1779 - sparse_categorical_accuracy: 0.9471
# Epoch 10/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.1635 - sparse_categorical_accuracy: 0.9521
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1778 - sparse_categorical_accuracy: 0.9512
# Fold 1
# Epoch 1/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9646 - student_loss: 0.1173 - distillation_loss: 0.0028
# Epoch 2/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9665 - student_loss: 0.1101 - distillation_loss: 0.0026
# Epoch 3/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9675 - student_loss: 0.1047 - distillation_loss: 0.0025
# Epoch 4/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9691 - student_loss: 0.1006 - distillation_loss: 0.0024
# Epoch 5/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9700 - student_loss: 0.0979 - distillation_loss: 0.0023
# Epoch 6/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9696 - student_loss: 0.0956 - distillation_loss: 0.0023
# Epoch 7/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9719 - student_loss: 0.0923 - distillation_loss: 0.0022
# Epoch 8/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9719 - student_loss: 0.0921 - distillation_loss: 0.0022
# Epoch 9/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9726 - student_loss: 0.0891 - distillation_loss: 0.0022
# Epoch 10/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9723 - student_loss: 0.0873 - distillation_loss: 0.0022
# 188/188 [==============================] - 0s 2ms/step - sparse_categorical_accuracy: 0.9512 - student_loss: 0.1741
# Epoch 1/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.1580 - sparse_categorical_accuracy: 0.9537
# Epoch 2/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.1468 - sparse_categorical_accuracy: 0.9562
# Epoch 3/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.1412 - sparse_categorical_accuracy: 0.9573
# Epoch 4/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.1351 - sparse_categorical_accuracy: 0.9605
# Epoch 5/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.1292 - sparse_categorical_accuracy: 0.9617
# Epoch 6/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.1277 - sparse_categorical_accuracy: 0.9620
# Epoch 7/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.1205 - sparse_categorical_accuracy: 0.9644
# Epoch 8/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.1185 - sparse_categorical_accuracy: 0.9647
# Epoch 9/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.1183 - sparse_categorical_accuracy: 0.9647
# Epoch 10/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.1134 - sparse_categorical_accuracy: 0.9664
# 188/188 [==============================] - 1s 2ms/step - loss: 0.1405 - sparse_categorical_accuracy: 0.9610
# Fold 2
# Epoch 1/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9714 - student_loss: 0.0931 - distillation_loss: 0.0022
# Epoch 2/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9728 - student_loss: 0.0884 - distillation_loss: 0.0022
# Epoch 3/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9737 - student_loss: 0.0851 - distillation_loss: 0.0021
# Epoch 4/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9733 - student_loss: 0.0858 - distillation_loss: 0.0021
# Epoch 5/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9740 - student_loss: 0.0852 - distillation_loss: 0.0021
# Epoch 6/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9759 - student_loss: 0.0806 - distillation_loss: 0.0020
# Epoch 7/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9745 - student_loss: 0.0818 - distillation_loss: 0.0020
# Epoch 8/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9754 - student_loss: 0.0788 - distillation_loss: 0.0019
# Epoch 9/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9767 - student_loss: 0.0764 - distillation_loss: 0.0019
# Epoch 10/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9765 - student_loss: 0.0754 - distillation_loss: 0.0019
# 188/188 [==============================] - 0s 2ms/step - sparse_categorical_accuracy: 0.9608 - student_loss: 0.1395
# Epoch 1/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.1167 - sparse_categorical_accuracy: 0.9653
# Epoch 2/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.1139 - sparse_categorical_accuracy: 0.9671
# Epoch 3/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.1110 - sparse_categorical_accuracy: 0.9671
# Epoch 4/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.1069 - sparse_categorical_accuracy: 0.9685
# Epoch 5/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.1086 - sparse_categorical_accuracy: 0.9677
# Epoch 6/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.1027 - sparse_categorical_accuracy: 0.9695
# Epoch 7/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.1015 - sparse_categorical_accuracy: 0.9703
# Epoch 8/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.1023 - sparse_categorical_accuracy: 0.9690
# Epoch 9/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0997 - sparse_categorical_accuracy: 0.9703
# Epoch 10/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0974 - sparse_categorical_accuracy: 0.9712
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1297 - sparse_categorical_accuracy: 0.9625
# Fold 3
# Epoch 1/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9740 - student_loss: 0.0848 - distillation_loss: 0.0021
# Epoch 2/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9752 - student_loss: 0.0794 - distillation_loss: 0.0020
# Epoch 3/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9748 - student_loss: 0.0802 - distillation_loss: 0.0020
# Epoch 4/10
# 1688/1688 [==============================] - 6s 3ms/step - sparse_categorical_accuracy: 0.9764 - student_loss: 0.0749 - distillation_loss: 0.0019
# Epoch 5/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9765 - student_loss: 0.0754 - distillation_loss: 0.0019
# Epoch 6/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9765 - student_loss: 0.0742 - distillation_loss: 0.0019
# Epoch 7/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9769 - student_loss: 0.0738 - distillation_loss: 0.0019
# Epoch 8/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9778 - student_loss: 0.0691 - distillation_loss: 0.0018
# Epoch 9/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9773 - student_loss: 0.0714 - distillation_loss: 0.0018
# Epoch 10/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9782 - student_loss: 0.0703 - distillation_loss: 0.0018
# 188/188 [==============================] - 0s 2ms/step - sparse_categorical_accuracy: 0.9728 - student_loss: 0.0924
# Epoch 1/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.1018 - sparse_categorical_accuracy: 0.9692
# Epoch 2/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0993 - sparse_categorical_accuracy: 0.9704
# Epoch 3/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0976 - sparse_categorical_accuracy: 0.9715
# Epoch 4/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0959 - sparse_categorical_accuracy: 0.9708
# Epoch 5/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0954 - sparse_categorical_accuracy: 0.9710
# Epoch 6/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0900 - sparse_categorical_accuracy: 0.9723
# Epoch 7/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0922 - sparse_categorical_accuracy: 0.9722
# Epoch 8/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0919 - sparse_categorical_accuracy: 0.9718
# Epoch 9/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0875 - sparse_categorical_accuracy: 0.9733
# Epoch 10/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0868 - sparse_categorical_accuracy: 0.9732
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1108 - sparse_categorical_accuracy: 0.9695
# Fold 4
# Epoch 1/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9758 - student_loss: 0.0741 - distillation_loss: 0.0019
# Epoch 2/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9773 - student_loss: 0.0722 - distillation_loss: 0.0018
# Epoch 3/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9777 - student_loss: 0.0701 - distillation_loss: 0.0018
# Epoch 4/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9784 - student_loss: 0.0686 - distillation_loss: 0.0017
# Epoch 5/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9787 - student_loss: 0.0683 - distillation_loss: 0.0017
# Epoch 6/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9788 - student_loss: 0.0658 - distillation_loss: 0.0017
# Epoch 7/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9791 - student_loss: 0.0654 - distillation_loss: 0.0017
# Epoch 8/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9790 - student_loss: 0.0659 - distillation_loss: 0.0017
# Epoch 9/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9808 - student_loss: 0.0617 - distillation_loss: 0.0016
# Epoch 10/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9794 - student_loss: 0.0634 - distillation_loss: 0.0017
# 188/188 [==============================] - 0s 2ms/step - sparse_categorical_accuracy: 0.9667 - student_loss: 0.1216
# Epoch 1/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0924 - sparse_categorical_accuracy: 0.9728
# Epoch 2/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0885 - sparse_categorical_accuracy: 0.9736
# Epoch 3/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0882 - sparse_categorical_accuracy: 0.9739
# Epoch 4/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0860 - sparse_categorical_accuracy: 0.9747
# Epoch 5/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0850 - sparse_categorical_accuracy: 0.9744
# Epoch 6/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0833 - sparse_categorical_accuracy: 0.9752
# Epoch 7/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0845 - sparse_categorical_accuracy: 0.9745
# Epoch 8/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0847 - sparse_categorical_accuracy: 0.9740
# Epoch 9/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0821 - sparse_categorical_accuracy: 0.9753
# Epoch 10/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0818 - sparse_categorical_accuracy: 0.9752
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1095 - sparse_categorical_accuracy: 0.9668
# Fold 5
# Epoch 1/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9781 - student_loss: 0.0716 - distillation_loss: 0.0018
# Epoch 2/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9795 - student_loss: 0.0657 - distillation_loss: 0.0017
# Epoch 3/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9789 - student_loss: 0.0670 - distillation_loss: 0.0017
# Epoch 4/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9795 - student_loss: 0.0644 - distillation_loss: 0.0017
# Epoch 5/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9803 - student_loss: 0.0640 - distillation_loss: 0.0016
# Epoch 6/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9792 - student_loss: 0.0647 - distillation_loss: 0.0017
# Epoch 7/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9807 - student_loss: 0.0626 - distillation_loss: 0.0016
# Epoch 8/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9804 - student_loss: 0.0617 - distillation_loss: 0.0016
# Epoch 9/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9809 - student_loss: 0.0615 - distillation_loss: 0.0016
# Epoch 10/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9810 - student_loss: 0.0606 - distillation_loss: 0.0016
# 188/188 [==============================] - 0s 2ms/step - sparse_categorical_accuracy: 0.9705 - student_loss: 0.1036
# Epoch 1/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0867 - sparse_categorical_accuracy: 0.9735
# Epoch 2/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0839 - sparse_categorical_accuracy: 0.9752
# Epoch 3/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0835 - sparse_categorical_accuracy: 0.9747
# Epoch 4/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0813 - sparse_categorical_accuracy: 0.9754
# Epoch 5/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0799 - sparse_categorical_accuracy: 0.9749
# Epoch 6/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0796 - sparse_categorical_accuracy: 0.9757
# Epoch 7/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0791 - sparse_categorical_accuracy: 0.9751
# Epoch 8/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0796 - sparse_categorical_accuracy: 0.9762
# Epoch 9/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0770 - sparse_categorical_accuracy: 0.9765
# Epoch 10/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0794 - sparse_categorical_accuracy: 0.9757
# 188/188 [==============================] - 0s 2ms/step - loss: 0.0927 - sparse_categorical_accuracy: 0.9680
# Fold 6
# Epoch 1/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9792 - student_loss: 0.0666 - distillation_loss: 0.0017
# Epoch 2/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9806 - student_loss: 0.0622 - distillation_loss: 0.0016
# Epoch 3/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9806 - student_loss: 0.0621 - distillation_loss: 0.0016
# Epoch 4/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9802 - student_loss: 0.0604 - distillation_loss: 0.0017
# Epoch 5/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9804 - student_loss: 0.0614 - distillation_loss: 0.0016
# Epoch 6/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9808 - student_loss: 0.0596 - distillation_loss: 0.0016
# Epoch 7/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9815 - student_loss: 0.0605 - distillation_loss: 0.0016
# Epoch 8/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9811 - student_loss: 0.0599 - distillation_loss: 0.0016
# Epoch 9/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9813 - student_loss: 0.0578 - distillation_loss: 0.0015
# Epoch 10/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9819 - student_loss: 0.0573 - distillation_loss: 0.0015
# 188/188 [==============================] - 0s 2ms/step - sparse_categorical_accuracy: 0.9708 - student_loss: 0.1199
# Epoch 1/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0813 - sparse_categorical_accuracy: 0.9757
# Epoch 2/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0789 - sparse_categorical_accuracy: 0.9764
# Epoch 3/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0764 - sparse_categorical_accuracy: 0.9767
# Epoch 4/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0786 - sparse_categorical_accuracy: 0.9759
# Epoch 5/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0743 - sparse_categorical_accuracy: 0.9774
# Epoch 6/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0750 - sparse_categorical_accuracy: 0.9774
# Epoch 7/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0766 - sparse_categorical_accuracy: 0.9767
# Epoch 8/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0712 - sparse_categorical_accuracy: 0.9780
# Epoch 9/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0739 - sparse_categorical_accuracy: 0.9769
# Epoch 10/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0714 - sparse_categorical_accuracy: 0.9779
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1119 - sparse_categorical_accuracy: 0.9682
# Fold 7
# Epoch 1/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9800 - student_loss: 0.0646 - distillation_loss: 0.0017
# Epoch 2/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9805 - student_loss: 0.0597 - distillation_loss: 0.0016
# Epoch 3/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9813 - student_loss: 0.0600 - distillation_loss: 0.0016
# Epoch 4/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9815 - student_loss: 0.0588 - distillation_loss: 0.0016
# Epoch 5/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9813 - student_loss: 0.0584 - distillation_loss: 0.0016
# Epoch 6/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9815 - student_loss: 0.0581 - distillation_loss: 0.0016
# Epoch 7/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9826 - student_loss: 0.0563 - distillation_loss: 0.0015
# Epoch 8/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9809 - student_loss: 0.0596 - distillation_loss: 0.0016
# Epoch 9/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9833 - student_loss: 0.0546 - distillation_loss: 0.0014
# Epoch 10/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9817 - student_loss: 0.0581 - distillation_loss: 0.0016
# 188/188 [==============================] - 0s 2ms/step - sparse_categorical_accuracy: 0.9688 - student_loss: 0.1043
# Epoch 1/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0807 - sparse_categorical_accuracy: 0.9765
# Epoch 2/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0734 - sparse_categorical_accuracy: 0.9782
# Epoch 3/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0725 - sparse_categorical_accuracy: 0.9776
# Epoch 4/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0757 - sparse_categorical_accuracy: 0.9766
# Epoch 5/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0735 - sparse_categorical_accuracy: 0.9778
# Epoch 6/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0728 - sparse_categorical_accuracy: 0.9775
# Epoch 7/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0696 - sparse_categorical_accuracy: 0.9792
# Epoch 8/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0718 - sparse_categorical_accuracy: 0.9777
# Epoch 9/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0696 - sparse_categorical_accuracy: 0.9794
# Epoch 10/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0719 - sparse_categorical_accuracy: 0.9785
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1104 - sparse_categorical_accuracy: 0.9688
# Fold 8
# Epoch 1/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9809 - student_loss: 0.0613 - distillation_loss: 0.0016
# Epoch 2/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9819 - student_loss: 0.0573 - distillation_loss: 0.0015
# Epoch 3/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9822 - student_loss: 0.0570 - distillation_loss: 0.0015
# Epoch 4/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9818 - student_loss: 0.0584 - distillation_loss: 0.0015
# Epoch 5/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9824 - student_loss: 0.0561 - distillation_loss: 0.0015
# Epoch 6/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9819 - student_loss: 0.0568 - distillation_loss: 0.0015
# Epoch 7/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9825 - student_loss: 0.0539 - distillation_loss: 0.0015
# Epoch 8/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9824 - student_loss: 0.0543 - distillation_loss: 0.0015
# Epoch 9/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9826 - student_loss: 0.0545 - distillation_loss: 0.0015
# Epoch 10/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9827 - student_loss: 0.0551 - distillation_loss: 0.0015
# 188/188 [==============================] - 0s 2ms/step - sparse_categorical_accuracy: 0.9718 - student_loss: 0.0990
# Epoch 1/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0781 - sparse_categorical_accuracy: 0.9770
# Epoch 2/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0725 - sparse_categorical_accuracy: 0.9776
# Epoch 3/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0711 - sparse_categorical_accuracy: 0.9781
# Epoch 4/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0713 - sparse_categorical_accuracy: 0.9789
# Epoch 5/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0702 - sparse_categorical_accuracy: 0.9786
# Epoch 6/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0711 - sparse_categorical_accuracy: 0.9783
# Epoch 7/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0693 - sparse_categorical_accuracy: 0.9787
# Epoch 8/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0707 - sparse_categorical_accuracy: 0.9785
# Epoch 9/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0698 - sparse_categorical_accuracy: 0.9794
# Epoch 10/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0701 - sparse_categorical_accuracy: 0.9785
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1018 - sparse_categorical_accuracy: 0.9733
# Fold 9
# Epoch 1/10
# 1688/1688 [==============================] - 7s 4ms/step - sparse_categorical_accuracy: 0.9806 - student_loss: 0.0615 - distillation_loss: 0.0016
# Epoch 2/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9814 - student_loss: 0.0584 - distillation_loss: 0.0016
# Epoch 3/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9828 - student_loss: 0.0540 - distillation_loss: 0.0015
# Epoch 4/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9835 - student_loss: 0.0527 - distillation_loss: 0.0015
# Epoch 5/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9823 - student_loss: 0.0546 - distillation_loss: 0.0015
# Epoch 6/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9819 - student_loss: 0.0559 - distillation_loss: 0.0015
# Epoch 7/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9824 - student_loss: 0.0545 - distillation_loss: 0.0015
# Epoch 8/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9828 - student_loss: 0.0545 - distillation_loss: 0.0015
# Epoch 9/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9824 - student_loss: 0.0549 - distillation_loss: 0.0015
# Epoch 10/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9829 - student_loss: 0.0525 - distillation_loss: 0.0015
# 188/188 [==============================] - 0s 2ms/step - sparse_categorical_accuracy: 0.9782 - student_loss: 0.0802
# Epoch 1/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0743 - sparse_categorical_accuracy: 0.9775
# Epoch 2/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0762 - sparse_categorical_accuracy: 0.9777
# Epoch 3/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0726 - sparse_categorical_accuracy: 0.9775
# Epoch 4/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0702 - sparse_categorical_accuracy: 0.9785
# Epoch 5/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0730 - sparse_categorical_accuracy: 0.9781
# Epoch 6/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0718 - sparse_categorical_accuracy: 0.9789
# Epoch 7/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0720 - sparse_categorical_accuracy: 0.9780
# Epoch 8/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0694 - sparse_categorical_accuracy: 0.9790
# Epoch 9/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0705 - sparse_categorical_accuracy: 0.9780
# Epoch 10/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0697 - sparse_categorical_accuracy: 0.9788
# 188/188 [==============================] - 0s 2ms/step - loss: 0.0675 - sparse_categorical_accuracy: 0.9823
# 313/313 [==============================] - 1s 2ms/step - sparse_categorical_accuracy: 0.9555 - student_loss: 0.2376
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1480 - sparse_categorical_accuracy: 0.9648

# %%
fig, axs = plt.subplots(2, 1, figsize=(15,15))

# Traning and validation results
axs[0].plot(np.mean(train_results_with_distillation, 1), '-D') 
axs[0].plot(np.mean(train_results_without_distillation, 1), '-x') 
axs[0].title.set_text('Training Accuracy with and without distillation') 
axs[0].legend(['With Distillation', 'Without Distillation'])  

# Test results
axs[1].plot(val_results_with_distillation, '-D') 
axs[1].plot(val_results_without_distillation, '-x') 
axs[1].title.set_text('Validation Accuracy with and without distillation') 
axs[1].legend(['With Distillation', 'Without Distillation'])

# %%
print(f"Test accuracy with disstillation {test_results_with_distillation['sparse_categorical_accuracy']}")
print(f"Test accuracy without disstillation {test_results_without_distillation['sparse_categorical_accuracy']}")
# Out:
# Test accuracy with disstillation 0.9555000066757202
# Test accuracy without disstillation 0.9648000001907349

# %%
# # # Save the model to load in future
# %mkdir ExpModels/Exp5

# studnet_model.save('ExpModels/Exp5/studnet_model')
# studnet_model_without_distillation.save('Exp1Models/Exp5/studnet_model_without_distillation')
# Out:
# The syntax of the command is incorrect.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 # # Save the model to load in future
#       2 get_ipython().run_line_magic('mkdir', 'ExpModels/Exp5')
# ----> 4 studnet_model.save('ExpModels/Exp5/studnet_model')
#       5 studnet_model_without_distillation.save('Exp1Models/Exp5/studnet_model_without_distillation')
#
# NameError: name 'studnet_model' is not defined
