# %%
# Experiment 1 KD with a lager model as student

# %%
# Split the training data into validation set and training set use a stratified k fold 
import numpy as np
from sklearn.model_selection import StratifiedKFold

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
from tensorflow.keras import datasets, layers, models, losses

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
# Knowledge distillation 
# Modified from source: https://keras.io/examples/vision/knowledge_distillation/

import Distiller

# %%
# Set up dataset
(x_train,y_train),(x_test,y_test) = datasets.mnist.load_data()
x_train.shape
# Out:
# (60000, 28, 28)

# %%
# Build the student model

def buildStudentModel():
    model = models.Sequential()
    model.add(layers.Conv2D(filters=6, kernel_size=(3,3), activation='relu', input_shape=(28, 28, 1)))
    model.add(layers.MaxPool2D(strides=2))
    
    model.add(layers.Conv2D(filters=6, kernel_size=(3,3), activation='relu'))
    model.add(layers.MaxPool2D(strides=2))
    
    model.add(layers.Conv2D(filters=16, kernel_size=(1,1), activation='relu'))
    model.add(layers.MaxPool2D(strides=2))
    model.add(layers.Flatten())
    model.add(layers.Dense(256, activation='relu'))
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dense(10, activation='softmax'))    
    
    return model

# %%
# Construct/load models

teacher_model = tf.keras.models.load_model('LeNetTeacherModel')
studnet_model = buildStudentModel()
studnet_model_without_distillation = keras.models.clone_model(studnet_model)

# Perform the stratified 10 fold cross validation
number_of_folds = 10

skf = StratifiedKFold(n_splits=number_of_folds)

# %%
# Haperparameter used in the experiment
number_of_epochs = 10

train_results_with_distillation = []
train_results_without_distillation = []

val_results_with_distillation = []
val_results_without_distillation = []

test_results_with_distillation = []
test_results_without_distillation = []

for i, (train_index, val_index) in enumerate(skf.split(x_train, y_train)):
    print(f"Fold {i}")
    
    x_train_fold = x_train[train_index]
    y_train_fold = y_train[train_index]
    
    x_val_fold = x_train[val_index]
    y_val_fold = y_train[val_index]
    
    distiller = Distiller.Distiller(student=studnet_model, teacher=teacher_model)
    distiller.compile(
        optimizer=keras.optimizers.Adam(),
        metrics=[keras.metrics.SparseCategoricalAccuracy()],
        student_loss_fn=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        distillation_loss_fn=keras.losses.KLDivergence(),
        alpha=0.1,
        temperature=10,
        #validation_data=(x_val_fold, y_val_fold)
    )
    # Distill teacher to student
    history = distiller.fit(x_train_fold, y_train_fold, epochs=number_of_epochs)
    train_results_with_distillation.append(history.history['sparse_categorical_accuracy'])
    
    score = distiller.evaluate(x_val_fold, y_val_fold, return_dict=True)
    val_results_with_distillation.append(score['sparse_categorical_accuracy'])
    
    
    # Train and evaluate the student model without distillation
    studnet_model_without_distillation.compile(
        optimizer=keras.optimizers.Adam(),
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[keras.metrics.SparseCategoricalAccuracy()],
        #validation_data=(x_val_fold, y_val_fold)
    )

    # Train and evaluate student trained from scratch.
    history = studnet_model_without_distillation.fit(x_train_fold, y_train_fold, epochs=number_of_epochs)
    train_results_without_distillation.append(history.history['sparse_categorical_accuracy'])
    
    score = studnet_model_without_distillation.evaluate(x_val_fold, y_val_fold, return_dict=True)
    val_results_without_distillation.append(score['sparse_categorical_accuracy'])
    
# Evaluate the models onb the test data when the training is complete    
# Evaluate student on test dataset
test_results_with_distillation = distiller.evaluate(x_test, y_test, return_dict=True)
test_results_without_distillation = studnet_model_without_distillation.evaluate(x_test, y_test, return_dict=True)
# Out:
# Fold 0
# Epoch 1/10
# D:\anaconda3\envs\tf\lib\site-packages\keras\backend.py:5582: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 1688/1688 [==============================] - 22s 12ms/step - sparse_categorical_accuracy: 0.8589 - student_loss: 0.4752 - distillation_loss: 0.0105
# Epoch 2/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9375 - student_loss: 0.1992 - distillation_loss: 0.0048
# Epoch 3/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9502 - student_loss: 0.1578 - distillation_loss: 0.0038
# Epoch 4/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9581 - student_loss: 0.1352 - distillation_loss: 0.0033
# Epoch 5/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9617 - student_loss: 0.1187 - distillation_loss: 0.0030
# Epoch 6/10
# 1688/1688 [==============================] - 21s 13ms/step - sparse_categorical_accuracy: 0.9653 - student_loss: 0.1087 - distillation_loss: 0.0027
# Epoch 7/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9681 - student_loss: 0.1001 - distillation_loss: 0.0026
# Epoch 8/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9696 - student_loss: 0.0951 - distillation_loss: 0.0024
# Epoch 9/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9724 - student_loss: 0.0864 - distillation_loss: 0.0022
# Epoch 10/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9738 - student_loss: 0.0800 - distillation_loss: 0.0021
# 188/188 [==============================] - 1s 5ms/step - sparse_categorical_accuracy: 0.9658 - student_loss: 0.1243
# Epoch 1/10
# 1688/1688 [==============================] - 15s 8ms/step - loss: 0.5362 - sparse_categorical_accuracy: 0.8647
# Epoch 2/10
# 1688/1688 [==============================] - 15s 9ms/step - loss: 0.2088 - sparse_categorical_accuracy: 0.9343
# Epoch 3/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.1622 - sparse_categorical_accuracy: 0.9490
# Epoch 4/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.1360 - sparse_categorical_accuracy: 0.9579
# Epoch 5/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.1207 - sparse_categorical_accuracy: 0.9622
# Epoch 6/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.1065 - sparse_categorical_accuracy: 0.9663
# Epoch 7/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0983 - sparse_categorical_accuracy: 0.9683
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0416 - sparse_categorical_accuracy: 0.9867
# Epoch 6/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0407 - sparse_categorical_accuracy: 0.9871
# Epoch 7/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0416 - sparse_categorical_accuracy: 0.9871
# Epoch 8/10
# 1688/1688 [==============================] - 15s 9ms/step - loss: 0.0389 - sparse_categorical_accuracy: 0.9872
# Epoch 9/10
# 1688/1688 [==============================] - 15s 9ms/step - loss: 0.0396 - sparse_categorical_accuracy: 0.9875
# Epoch 10/10
# 1688/1688 [==============================] - 15s 9ms/step - loss: 0.0366 - sparse_categorical_accuracy: 0.9885
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0540 - sparse_categorical_accuracy: 0.9832
# Fold 4
# Epoch 1/10
# 1688/1688 [==============================] - 23s 13ms/step - sparse_categorical_accuracy: 0.9867 - student_loss: 0.0451 - distillation_loss: 0.0013
# Epoch 2/10
# 1688/1688 [==============================] - 23s 13ms/step - sparse_categorical_accuracy: 0.9880 - student_loss: 0.0383 - distillation_loss: 0.0012
# Epoch 3/10
# 1688/1688 [==============================] - 23s 13ms/step - sparse_categorical_accuracy: 0.9881 - student_loss: 0.0409 - distillation_loss: 0.0012
# Epoch 4/10
# 1688/1688 [==============================] - 23s 13ms/step - sparse_categorical_accuracy: 0.9875 - student_loss: 0.0409 - distillation_loss: 0.0012
# Epoch 5/10
# 1688/1688 [==============================] - 23s 13ms/step - sparse_categorical_accuracy: 0.9881 - student_loss: 0.0394 - distillation_loss: 0.0012
# Epoch 6/10
# 1688/1688 [==============================] - 23s 13ms/step - sparse_categorical_accuracy: 0.9879 - student_loss: 0.0383 - distillation_loss: 0.0012
# Epoch 7/10
# 1688/1688 [==============================] - 23s 13ms/step - sparse_categorical_accuracy: 0.9877 - student_loss: 0.0396 - distillation_loss: 0.0012
# Epoch 8/10
# 1688/1688 [==============================] - 23s 13ms/step - sparse_categorical_accuracy: 0.9883 - student_loss: 0.0376 - distillation_loss: 0.0012
# Epoch 9/10
# 1688/1688 [==============================] - 23s 13ms/step - sparse_categorical_accuracy: 0.9888 - student_loss: 0.0383 - distillation_loss: 0.0011
# Epoch 10/10
# 1688/1688 [==============================] - 22s 13ms/step - sparse_categorical_accuracy: 0.9896 - student_loss: 0.0335 - distillation_loss: 0.0011
# 188/188 [==============================] - 1s 5ms/step - sparse_categorical_accuracy: 0.9820 - student_loss: 0.0728
# Epoch 1/10
# 1688/1688 [==============================] - 16s 9ms/step - loss: 0.0469 - sparse_categorical_accuracy: 0.9858
# Epoch 2/10
# 1688/1688 [==============================] - 15s 9ms/step - loss: 0.0402 - sparse_categorical_accuracy: 0.9874
# Epoch 3/10
# 1688/1688 [==============================] - 15s 9ms/step - loss: 0.0398 - sparse_categorical_accuracy: 0.9878
# Epoch 4/10
# 1688/1688 [==============================] - 15s 9ms/step - loss: 0.0373 - sparse_categorical_accuracy: 0.9887
# Epoch 5/10
# 1688/1688 [==============================] - 15s 9ms/step - loss: 0.0358 - sparse_categorical_accuracy: 0.9885
# Epoch 6/10
# 1688/1688 [==============================] - 15s 9ms/step - loss: 0.0393 - sparse_categorical_accuracy: 0.9879
# Epoch 7/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0361 - sparse_categorical_accuracy: 0.9887
# Epoch 8/10
# 1688/1688 [==============================] - 15s 9ms/step - loss: 0.0374 - sparse_categorical_accuracy: 0.9887
# Epoch 9/10
# 1688/1688 [==============================] - 14s 9ms/step - loss: 0.0361 - sparse_categorical_accuracy: 0.9886
# Epoch 10/10
# 1688/1688 [==============================] - 14s 9ms/step - loss: 0.0345 - sparse_categorical_accuracy: 0.9892
# 188/188 [==============================] - 1s 5ms/step - loss: 0.0673 - sparse_categorical_accuracy: 0.9822
# Fold 5
# Epoch 1/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9872 - student_loss: 0.0441 - distillation_loss: 0.0013
# Epoch 2/10
# 1688/1688 [==============================] - 21s 13ms/step - sparse_categorical_accuracy: 0.9886 - student_loss: 0.0360 - distillation_loss: 0.0011
# Epoch 3/10
# 1688/1688 [==============================] - 21s 13ms/step - sparse_categorical_accuracy: 0.9883 - student_loss: 0.0394 - distillation_loss: 0.0012
# Epoch 4/10
# 1688/1688 [==============================] - 21s 13ms/step - sparse_categorical_accuracy: 0.9879 - student_loss: 0.0414 - distillation_loss: 0.0012
# Epoch 5/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9891 - student_loss: 0.0355 - distillation_loss: 0.0011
# Epoch 6/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9895 - student_loss: 0.0330 - distillation_loss: 0.0011
# Epoch 7/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9886 - student_loss: 0.0381 - distillation_loss: 0.0012
# Epoch 8/10
# 1688/1688 [==============================] - 20s 12ms/step - sparse_categorical_accuracy: 0.9891 - student_loss: 0.0359 - distillation_loss: 0.0011
# Epoch 9/10
# 1688/1688 [==============================] - 20s 12ms/step - sparse_categorical_accuracy: 0.9881 - student_loss: 0.0412 - distillation_loss: 0.0012
# Epoch 10/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9895 - student_loss: 0.0336 - distillation_loss: 0.0011
# 188/188 [==============================] - 1s 5ms/step - sparse_categorical_accuracy: 0.9780 - student_loss: 0.0773
# Epoch 1/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0421 - sparse_categorical_accuracy: 0.9879
# Epoch 2/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0371 - sparse_categorical_accuracy: 0.9891
# Epoch 3/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0374 - sparse_categorical_accuracy: 0.9887
# Epoch 4/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0349 - sparse_categorical_accuracy: 0.9890
# Epoch 5/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0376 - sparse_categorical_accuracy: 0.9884
# Epoch 6/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0333 - sparse_categorical_accuracy: 0.9896
# Epoch 7/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0386 - sparse_categorical_accuracy: 0.9880
# Epoch 8/10
# 1688/1688 [==============================] - 15s 9ms/step - loss: 0.0313 - sparse_categorical_accuracy: 0.9907
# Epoch 9/10
# 1688/1688 [==============================] - 15s 9ms/step - loss: 0.0367 - sparse_categorical_accuracy: 0.9891
# Epoch 10/10
# 1688/1688 [==============================] - 15s 9ms/step - loss: 0.0315 - sparse_categorical_accuracy: 0.9904
# 188/188 [==============================] - 1s 5ms/step - loss: 0.0490 - sparse_categorical_accuracy: 0.9853
# Fold 6
# Epoch 1/10
# 1688/1688 [==============================] - 22s 13ms/step - sparse_categorical_accuracy: 0.9874 - student_loss: 0.0439 - distillation_loss: 0.0013
# Epoch 2/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9899 - student_loss: 0.0352 - distillation_loss: 0.0011
# Epoch 3/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9882 - student_loss: 0.0406 - distillation_loss: 0.0012
# Epoch 4/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9890 - student_loss: 0.0364 - distillation_loss: 0.0011
# Epoch 5/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9891 - student_loss: 0.0347 - distillation_loss: 0.0011
# Epoch 6/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9888 - student_loss: 0.0376 - distillation_loss: 0.0012
# Epoch 7/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9900 - student_loss: 0.0333 - distillation_loss: 0.0011
# Epoch 8/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9890 - student_loss: 0.0360 - distillation_loss: 0.0011
# Epoch 9/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9895 - student_loss: 0.0341 - distillation_loss: 0.0011
# Epoch 10/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9879 - student_loss: 0.0428 - distillation_loss: 0.0013
# 188/188 [==============================] - 1s 5ms/step - sparse_categorical_accuracy: 0.9753 - student_loss: 0.1219
# Epoch 1/10
# 1688/1688 [==============================] - 16s 9ms/step - loss: 0.0367 - sparse_categorical_accuracy: 0.9893
# Epoch 2/10
# 1688/1688 [==============================] - 15s 9ms/step - loss: 0.0346 - sparse_categorical_accuracy: 0.9891
# Epoch 3/10
# 1688/1688 [==============================] - 15s 9ms/step - loss: 0.0375 - sparse_categorical_accuracy: 0.9887
# Epoch 4/10
# 1688/1688 [==============================] - 15s 9ms/step - loss: 0.0349 - sparse_categorical_accuracy: 0.9894
# Epoch 5/10
# 1688/1688 [==============================] - 15s 9ms/step - loss: 0.0329 - sparse_categorical_accuracy: 0.9906
# Epoch 6/10
# 1688/1688 [==============================] - 15s 9ms/step - loss: 0.0329 - sparse_categorical_accuracy: 0.9903
# Epoch 7/10
# 1688/1688 [==============================] - 15s 9ms/step - loss: 0.0365 - sparse_categorical_accuracy: 0.9895
# Epoch 8/10
# 1688/1688 [==============================] - 15s 9ms/step - loss: 0.0356 - sparse_categorical_accuracy: 0.9893
# Epoch 9/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0325 - sparse_categorical_accuracy: 0.9905
# Epoch 10/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0344 - sparse_categorical_accuracy: 0.9896
# 188/188 [==============================] - 1s 5ms/step - loss: 0.1004 - sparse_categorical_accuracy: 0.9782
# Fold 7
# Epoch 1/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9875 - student_loss: 0.0443 - distillation_loss: 0.0012
# Epoch 2/10
# 1688/1688 [==============================] - 20s 12ms/step - sparse_categorical_accuracy: 0.9893 - student_loss: 0.0369 - distillation_loss: 0.0011
# Epoch 3/10
# 1688/1688 [==============================] - 20s 12ms/step - sparse_categorical_accuracy: 0.9902 - student_loss: 0.0335 - distillation_loss: 0.0011
# Epoch 4/10
# 1688/1688 [==============================] - 20s 12ms/step - sparse_categorical_accuracy: 0.9881 - student_loss: 0.0430 - distillation_loss: 0.0012
# Epoch 5/10
# 1688/1688 [==============================] - 20s 12ms/step - sparse_categorical_accuracy: 0.9898 - student_loss: 0.0348 - distillation_loss: 0.0011
# Epoch 6/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9883 - student_loss: 0.0382 - distillation_loss: 0.0012
# Epoch 7/10
# 1688/1688 [==============================] - 21s 13ms/step - sparse_categorical_accuracy: 0.9900 - student_loss: 0.0355 - distillation_loss: 0.0011
# Epoch 8/10
# 1688/1688 [==============================] - 21s 13ms/step - sparse_categorical_accuracy: 0.9907 - student_loss: 0.0329 - distillation_loss: 0.0011
# Epoch 9/10
# 1688/1688 [==============================] - 22s 13ms/step - sparse_categorical_accuracy: 0.9891 - student_loss: 0.0376 - distillation_loss: 0.0012
# Epoch 10/10
# 1688/1688 [==============================] - 21s 13ms/step - sparse_categorical_accuracy: 0.9891 - student_loss: 0.0368 - distillation_loss: 0.0012
# 188/188 [==============================] - 1s 5ms/step - sparse_categorical_accuracy: 0.9833 - student_loss: 0.0688
# Epoch 1/10
# 1688/1688 [==============================] - 15s 8ms/step - loss: 0.0418 - sparse_categorical_accuracy: 0.9887
# Epoch 2/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0382 - sparse_categorical_accuracy: 0.9892
# Epoch 3/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0375 - sparse_categorical_accuracy: 0.9889
# Epoch 4/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0389 - sparse_categorical_accuracy: 0.9891
# Epoch 5/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0310 - sparse_categorical_accuracy: 0.9909
# Epoch 6/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0342 - sparse_categorical_accuracy: 0.9897
# Epoch 7/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0347 - sparse_categorical_accuracy: 0.9898
# Epoch 8/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0329 - sparse_categorical_accuracy: 0.9901
# Epoch 9/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0331 - sparse_categorical_accuracy: 0.9901
# Epoch 10/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0342 - sparse_categorical_accuracy: 0.9902
# 188/188 [==============================] - 1s 5ms/step - loss: 0.0522 - sparse_categorical_accuracy: 0.9857
# Fold 8
# Epoch 1/10
# 1688/1688 [==============================] - 22s 12ms/step - sparse_categorical_accuracy: 0.9895 - student_loss: 0.0394 - distillation_loss: 0.0011
# Epoch 2/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9895 - student_loss: 0.0390 - distillation_loss: 0.0011
# Epoch 3/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9903 - student_loss: 0.0337 - distillation_loss: 0.0010
# Epoch 4/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9893 - student_loss: 0.0382 - distillation_loss: 0.0011
# Epoch 5/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9892 - student_loss: 0.0401 - distillation_loss: 0.0011
# Epoch 6/10
# 1688/1688 [==============================] - 21s 13ms/step - sparse_categorical_accuracy: 0.9901 - student_loss: 0.0337 - distillation_loss: 0.0011
# Epoch 7/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9901 - student_loss: 0.0359 - distillation_loss: 0.0011
# Epoch 8/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9904 - student_loss: 0.0328 - distillation_loss: 0.0010
# Epoch 9/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9901 - student_loss: 0.0342 - distillation_loss: 0.0010
# Epoch 10/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9890 - student_loss: 0.0382 - distillation_loss: 0.0011
# 188/188 [==============================] - 1s 5ms/step - sparse_categorical_accuracy: 0.9825 - student_loss: 0.0892
# Epoch 1/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0395 - sparse_categorical_accuracy: 0.9895
# Epoch 2/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0400 - sparse_categorical_accuracy: 0.9896
# Epoch 3/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0356 - sparse_categorical_accuracy: 0.9901
# Epoch 4/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0365 - sparse_categorical_accuracy: 0.9898
# Epoch 5/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0381 - sparse_categorical_accuracy: 0.9895
# Epoch 6/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0325 - sparse_categorical_accuracy: 0.9903
# Epoch 7/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0380 - sparse_categorical_accuracy: 0.9892
# Epoch 8/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0320 - sparse_categorical_accuracy: 0.9905
# Epoch 9/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0301 - sparse_categorical_accuracy: 0.9910
# Epoch 10/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0371 - sparse_categorical_accuracy: 0.9895
# 188/188 [==============================] - 1s 5ms/step - loss: 0.0512 - sparse_categorical_accuracy: 0.9847
# Fold 9
# Epoch 1/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9896 - student_loss: 0.0386 - distillation_loss: 0.0011
# Epoch 2/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9888 - student_loss: 0.0406 - distillation_loss: 0.0012
# Epoch 3/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9885 - student_loss: 0.0416 - distillation_loss: 0.0012
# Epoch 4/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9908 - student_loss: 0.0320 - distillation_loss: 0.0010
# Epoch 5/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9908 - student_loss: 0.0331 - distillation_loss: 0.0011
# Epoch 6/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9903 - student_loss: 0.0355 - distillation_loss: 0.0011
# Epoch 7/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9894 - student_loss: 0.0375 - distillation_loss: 0.0011
# Epoch 8/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9900 - student_loss: 0.0360 - distillation_loss: 0.0011
# Epoch 9/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9897 - student_loss: 0.0372 - distillation_loss: 0.0011
# Epoch 10/10
# 1688/1688 [==============================] - 21s 12ms/step - sparse_categorical_accuracy: 0.9907 - student_loss: 0.0331 - distillation_loss: 0.0011
# 188/188 [==============================] - 1s 5ms/step - sparse_categorical_accuracy: 0.9857 - student_loss: 0.0554
# Epoch 1/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0397 - sparse_categorical_accuracy: 0.9889
# Epoch 2/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0398 - sparse_categorical_accuracy: 0.9892
# Epoch 3/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0390 - sparse_categorical_accuracy: 0.9894
# Epoch 4/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0337 - sparse_categorical_accuracy: 0.9902
# Epoch 5/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0391 - sparse_categorical_accuracy: 0.9894
# Epoch 6/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0348 - sparse_categorical_accuracy: 0.9904
# Epoch 7/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0386 - sparse_categorical_accuracy: 0.9893
# Epoch 8/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0290 - sparse_categorical_accuracy: 0.9916
# Epoch 9/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0350 - sparse_categorical_accuracy: 0.9905
# Epoch 10/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0399 - sparse_categorical_accuracy: 0.9891
# 188/188 [==============================] - 1s 5ms/step - loss: 0.0404 - sparse_categorical_accuracy: 0.9922
# 313/313 [==============================] - 2s 5ms/step - sparse_categorical_accuracy: 0.9677 - student_loss: 0.2515
# 313/313 [==============================] - 2s 5ms/step - loss: 0.1945 - sparse_categorical_accuracy: 0.9737

# %%
fig, axs = plt.subplots(2, 1, figsize=(15,15))

# Traning and validation results
axs[0].plot(np.mean(train_results_with_distillation, 1), '-D') 
axs[0].plot(np.mean(train_results_without_distillation, 1), '-x') 
axs[0].title.set_text('Training Accuracy with and without distillation') 
axs[0].legend(['With Distillation', 'Without Distillation'])  

# Test results
axs[1].plot(val_results_with_distillation, '-D') 
axs[1].plot(val_results_without_distillation, '-x') 
axs[1].title.set_text('Validation Accuracy with and without distillation') 
axs[1].legend(['With Distillation', 'Without Distillation'])

# %%
print(f"Test accuracy with disstillation {test_results_with_distillation['sparse_categorical_accuracy']}")
print(f"Test accuracy without disstillation {test_results_without_distillation['sparse_categorical_accuracy']}")
# Out:
# Test accuracy with disstillation 0.9677000045776367
# Test accuracy without disstillation 0.9736999869346619

# %%
# # Save the model to load in future
# %mkdir -p Exp1Models

# studnet_model.save('Exp1Models/studnet_model')
# studnet_model_without_distillation.save('Exp1Models/studnet_model_without_distillation')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Exp1Models/studnet_model\assets
# INFO:tensorflow:Assets written to: Exp1Models/studnet_model\assets
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Exp1Models/studnet_model_without_distillation\assets
# INFO:tensorflow:Assets written to: Exp1Models/studnet_model_without_distillation\assets
