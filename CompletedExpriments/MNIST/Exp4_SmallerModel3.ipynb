# %%
# Experiment 4 KD with a much smaller model as student

# %%
# Split the training data into validation set and training set use a stratified k fold 
import numpy as np
from sklearn.model_selection import StratifiedKFold

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
from tensorflow.keras import datasets, layers, models, losses

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
# Knowledge distillation 
# Modified from source: https://keras.io/examples/vision/knowledge_distillation/

import Distiller

# %%
# Set up dataset
(x_train,y_train),(x_test,y_test) = datasets.mnist.load_data()
x_train.shape
# Out:
# (60000, 28, 28)

# %%
# Build the student model

def buildStudentModel():
    model = models.Sequential()
    model.add(layers.Conv2D(filters=3, kernel_size=(5,5), activation='relu', input_shape=(28, 28, 1)))
    model.add(layers.MaxPool2D(strides=2))
    model.add(layers.Flatten())
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(10, activation='softmax'))    
    
    return model

# %%
# Construct/load models

teacher_model = tf.keras.models.load_model('LeNetTeacherModel')
studnet_model = buildStudentModel()
studnet_model_without_distillation = keras.models.clone_model(studnet_model)

# Perform the stratified 10 fold cross validation
number_of_folds = 10

skf = StratifiedKFold(n_splits=number_of_folds)

# %%
# Haperparameter used in the experiment
number_of_epochs = 10

train_results_with_distillation = []
train_results_without_distillation = []

val_results_with_distillation = []
val_results_without_distillation = []

test_results_with_distillation = []
test_results_without_distillation = []

for i, (train_index, val_index) in enumerate(skf.split(x_train, y_train)):
    print(f"Fold {i}")
    
    x_train_fold = x_train[train_index]
    y_train_fold = y_train[train_index]
    
    x_val_fold = x_train[val_index]
    y_val_fold = y_train[val_index]
    
    distiller = Distiller.Distiller(student=studnet_model, teacher=teacher_model)
    distiller.compile(
        optimizer=keras.optimizers.Adam(),
        metrics=[keras.metrics.SparseCategoricalAccuracy()],
        student_loss_fn=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        distillation_loss_fn=keras.losses.KLDivergence(),
        alpha=0.1,
        temperature=10,
        #validation_data=(x_val_fold, y_val_fold)
    )
    # Distill teacher to student
    history = distiller.fit(x_train_fold, y_train_fold, epochs=number_of_epochs)
    train_results_with_distillation.append(history.history['sparse_categorical_accuracy'])
    
    score = distiller.evaluate(x_val_fold, y_val_fold, return_dict=True)
    val_results_with_distillation.append(score['sparse_categorical_accuracy'])
    
    
    # Train and evaluate the student model without distillation
    studnet_model_without_distillation.compile(
        optimizer=keras.optimizers.Adam(),
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[keras.metrics.SparseCategoricalAccuracy()],
    )

    # Train and evaluate student trained from scratch.
    history = studnet_model_without_distillation.fit(x_train_fold, y_train_fold, epochs=number_of_epochs)
    train_results_without_distillation.append(history.history['sparse_categorical_accuracy'])
    
    score = studnet_model_without_distillation.evaluate(x_val_fold, y_val_fold, return_dict=True)
    val_results_without_distillation.append(score['sparse_categorical_accuracy'])
    
# Evaluate the models onb the test data when the training is complete    
# Evaluate student on test dataset
test_results_with_distillation = distiller.evaluate(x_test, y_test, return_dict=True)
test_results_without_distillation = studnet_model_without_distillation.evaluate(x_test, y_test, return_dict=True)
# Out:
# Fold 0
# Epoch 1/10
# D:\anaconda3\envs\tf\lib\site-packages\keras\backend.py:5582: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 1688/1688 [==============================] - 7s 4ms/step - sparse_categorical_accuracy: 0.8318 - student_loss: 1.3680 - distillation_loss: 0.0137
# Epoch 2/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9370 - student_loss: 0.2309 - distillation_loss: 0.0049
# Epoch 3/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9543 - student_loss: 0.1567 - distillation_loss: 0.0035
# Epoch 4/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9650 - student_loss: 0.1206 - distillation_loss: 0.0027
# Epoch 5/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9693 - student_loss: 0.1027 - distillation_loss: 0.0025
# Epoch 6/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9730 - student_loss: 0.0912 - distillation_loss: 0.0022
# Epoch 7/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9760 - student_loss: 0.0799 - distillation_loss: 0.0019
# Epoch 8/10
# 1688/1688 [==============================] - 6s 3ms/step - sparse_categorical_accuracy: 0.9773 - student_loss: 0.0748 - distillation_loss: 0.0019
# Epoch 9/10
# 1688/1688 [==============================] - 7s 4ms/step - sparse_categorical_accuracy: 0.9787 - student_loss: 0.0719 - distillation_loss: 0.0018
# Epoch 10/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9811 - student_loss: 0.0627 - distillation_loss: 0.0016
# 188/188 [==============================] - 0s 2ms/step - sparse_categorical_accuracy: 0.9728 - student_loss: 0.1288
# Epoch 1/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 2.2775 - sparse_categorical_accuracy: 0.8384
# Epoch 2/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.2783 - sparse_categorical_accuracy: 0.9265
# Epoch 3/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.1771 - sparse_categorical_accuracy: 0.9494
# Epoch 4/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.1332 - sparse_categorical_accuracy: 0.9611
# Epoch 5/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.1068 - sparse_categorical_accuracy: 0.9688
# Epoch 6/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0936 - sparse_categorical_accuracy: 0.9724
# Epoch 7/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0816 - sparse_categorical_accuracy: 0.9759
# Epoch 8/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0732 - sparse_categorical_accuracy: 0.9776
# Epoch 9/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0631 - sparse_categorical_accuracy: 0.9814
# Epoch 10/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0602 - sparse_categorical_accuracy: 0.9814
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1222 - sparse_categorical_accuracy: 0.9717
# Fold 1
# Epoch 1/10
# 1688/1688 [==============================] - 7s 4ms/step - sparse_categorical_accuracy: 0.9792 - student_loss: 0.0708 - distillation_loss: 0.0017
# Epoch 2/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9821 - student_loss: 0.0612 - distillation_loss: 0.0015
# Epoch 3/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9841 - student_loss: 0.0552 - distillation_loss: 0.0014
# Epoch 4/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9832 - student_loss: 0.0568 - distillation_loss: 0.0015
# Epoch 5/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9844 - student_loss: 0.0513 - distillation_loss: 0.0014
# Epoch 6/10
# 1688/1688 [==============================] - 7s 4ms/step - sparse_categorical_accuracy: 0.9855 - student_loss: 0.0485 - distillation_loss: 0.0013
# Epoch 7/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9854 - student_loss: 0.0492 - distillation_loss: 0.0013
# Epoch 8/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9866 - student_loss: 0.0452 - distillation_loss: 0.0012
# Epoch 9/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9867 - student_loss: 0.0464 - distillation_loss: 0.0012
# Epoch 10/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9867 - student_loss: 0.0427 - distillation_loss: 0.0012
# 188/188 [==============================] - 0s 2ms/step - sparse_categorical_accuracy: 0.9672 - student_loss: 0.1658
# Epoch 1/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0687 - sparse_categorical_accuracy: 0.9803
# Epoch 2/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0551 - sparse_categorical_accuracy: 0.9837
# Epoch 3/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0518 - sparse_categorical_accuracy: 0.9844
# Epoch 4/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0489 - sparse_categorical_accuracy: 0.9850
# Epoch 5/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0467 - sparse_categorical_accuracy: 0.9862
# Epoch 6/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0435 - sparse_categorical_accuracy: 0.9871
# Epoch 7/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0433 - sparse_categorical_accuracy: 0.9869
# Epoch 8/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0380 - sparse_categorical_accuracy: 0.9890
# Epoch 9/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0378 - sparse_categorical_accuracy: 0.9885
# Epoch 10/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0434 - sparse_categorical_accuracy: 0.9873
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1076 - sparse_categorical_accuracy: 0.9795
# Fold 2
# Epoch 1/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9857 - student_loss: 0.0548 - distillation_loss: 0.0013
# Epoch 2/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9859 - student_loss: 0.0507 - distillation_loss: 0.0013
# Epoch 3/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9876 - student_loss: 0.0442 - distillation_loss: 0.0012
# Epoch 4/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9875 - student_loss: 0.0423 - distillation_loss: 0.0012
# Epoch 5/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9890 - student_loss: 0.0392 - distillation_loss: 0.0011
# Epoch 6/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9882 - student_loss: 0.0427 - distillation_loss: 0.0011
# Epoch 7/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9883 - student_loss: 0.0419 - distillation_loss: 0.0012
# Epoch 8/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9897 - student_loss: 0.0352 - distillation_loss: 0.0011
# Epoch 9/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9889 - student_loss: 0.0404 - distillation_loss: 0.0011
# Epoch 10/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9892 - student_loss: 0.0381 - distillation_loss: 0.0011
# 188/188 [==============================] - 0s 2ms/step - sparse_categorical_accuracy: 0.9782 - student_loss: 0.1046
# Epoch 1/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0503 - sparse_categorical_accuracy: 0.9869
# Epoch 2/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0413 - sparse_categorical_accuracy: 0.9879
# Epoch 3/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0413 - sparse_categorical_accuracy: 0.9892
# Epoch 4/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0365 - sparse_categorical_accuracy: 0.9899
# Epoch 5/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0379 - sparse_categorical_accuracy: 0.9897
# Epoch 6/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0320 - sparse_categorical_accuracy: 0.9908
# Epoch 7/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0378 - sparse_categorical_accuracy: 0.9902
# Epoch 8/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0365 - sparse_categorical_accuracy: 0.9901
# Epoch 9/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0305 - sparse_categorical_accuracy: 0.9916
# Epoch 10/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0290 - sparse_categorical_accuracy: 0.9919
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1128 - sparse_categorical_accuracy: 0.9812
# Fold 3
# Epoch 1/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9884 - student_loss: 0.0436 - distillation_loss: 0.0011
# Epoch 2/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9890 - student_loss: 0.0382 - distillation_loss: 0.0011
# Epoch 3/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9899 - student_loss: 0.0376 - distillation_loss: 0.0010
# Epoch 4/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9896 - student_loss: 0.0379 - distillation_loss: 0.0011
# Epoch 5/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9902 - student_loss: 0.0379 - distillation_loss: 0.0010
# Epoch 6/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9903 - student_loss: 0.0357 - distillation_loss: 0.0010
# Epoch 7/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9902 - student_loss: 0.0373 - distillation_loss: 0.0011
# Epoch 8/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9904 - student_loss: 0.0342 - distillation_loss: 0.0010
# Epoch 9/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9911 - student_loss: 0.0358 - distillation_loss: 9.9526e-04
# Epoch 10/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9909 - student_loss: 0.0352 - distillation_loss: 0.0010
# 188/188 [==============================] - 0s 2ms/step - sparse_categorical_accuracy: 0.9837 - student_loss: 0.0710
# Epoch 1/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0455 - sparse_categorical_accuracy: 0.9893
# Epoch 2/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0384 - sparse_categorical_accuracy: 0.9902
# Epoch 3/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0350 - sparse_categorical_accuracy: 0.9910
# Epoch 4/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0297 - sparse_categorical_accuracy: 0.9924
# Epoch 5/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0340 - sparse_categorical_accuracy: 0.9916
# Epoch 6/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0343 - sparse_categorical_accuracy: 0.9920
# Epoch 7/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0309 - sparse_categorical_accuracy: 0.9926
# Epoch 8/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0293 - sparse_categorical_accuracy: 0.9928
# Epoch 9/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0298 - sparse_categorical_accuracy: 0.9925
# Epoch 10/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0289 - sparse_categorical_accuracy: 0.9934
# 188/188 [==============================] - 0s 2ms/step - loss: 0.0728 - sparse_categorical_accuracy: 0.9870
# Fold 4
# Epoch 1/10
# 1688/1688 [==============================] - 7s 4ms/step - sparse_categorical_accuracy: 0.9904 - student_loss: 0.0385 - distillation_loss: 0.0010
# Epoch 2/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9904 - student_loss: 0.0406 - distillation_loss: 0.0011
# Epoch 3/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9918 - student_loss: 0.0316 - distillation_loss: 9.3393e-04
# Epoch 4/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9910 - student_loss: 0.0382 - distillation_loss: 0.0010
# Epoch 5/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9910 - student_loss: 0.0350 - distillation_loss: 9.9415e-04
# Epoch 6/10
# 1688/1688 [==============================] - 7s 4ms/step - sparse_categorical_accuracy: 0.9916 - student_loss: 0.0317 - distillation_loss: 9.2915e-04
# Epoch 7/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9927 - student_loss: 0.0299 - distillation_loss: 8.9416e-04
# Epoch 8/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9911 - student_loss: 0.0368 - distillation_loss: 0.0010
# Epoch 9/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9914 - student_loss: 0.0363 - distillation_loss: 9.6132e-04
# Epoch 10/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9923 - student_loss: 0.0323 - distillation_loss: 9.0708e-04
# 188/188 [==============================] - 1s 2ms/step - sparse_categorical_accuracy: 0.9788 - student_loss: 0.1531
# Epoch 1/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0396 - sparse_categorical_accuracy: 0.9922
# Epoch 2/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0282 - sparse_categorical_accuracy: 0.9935
# Epoch 3/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0326 - sparse_categorical_accuracy: 0.9932
# Epoch 4/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0315 - sparse_categorical_accuracy: 0.9930
# Epoch 5/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0338 - sparse_categorical_accuracy: 0.9930
# Epoch 6/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0339 - sparse_categorical_accuracy: 0.9931
# Epoch 7/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0266 - sparse_categorical_accuracy: 0.9941
# Epoch 8/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0322 - sparse_categorical_accuracy: 0.9934
# Epoch 9/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0328 - sparse_categorical_accuracy: 0.9931
# Epoch 10/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0331 - sparse_categorical_accuracy: 0.9938
# 188/188 [==============================] - 0s 2ms/step - loss: 0.0825 - sparse_categorical_accuracy: 0.9868
# Fold 5
# Epoch 1/10
# 1688/1688 [==============================] - 7s 4ms/step - sparse_categorical_accuracy: 0.9901 - student_loss: 0.0467 - distillation_loss: 0.0011
# Epoch 2/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9923 - student_loss: 0.0325 - distillation_loss: 9.3578e-04
# Epoch 3/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9920 - student_loss: 0.0352 - distillation_loss: 9.3983e-04
# Epoch 4/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9924 - student_loss: 0.0347 - distillation_loss: 9.2527e-04
# Epoch 5/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9923 - student_loss: 0.0346 - distillation_loss: 9.2905e-04
# Epoch 6/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9930 - student_loss: 0.0312 - distillation_loss: 8.4362e-04
# Epoch 7/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9927 - student_loss: 0.0318 - distillation_loss: 9.0773e-04
# Epoch 8/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9928 - student_loss: 0.0354 - distillation_loss: 9.2176e-04
# Epoch 9/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9932 - student_loss: 0.0308 - distillation_loss: 8.6768e-04
# Epoch 10/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9936 - student_loss: 0.0287 - distillation_loss: 8.3749e-04
# 188/188 [==============================] - 0s 2ms/step - sparse_categorical_accuracy: 0.9900 - student_loss: 0.0499
# Epoch 1/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0414 - sparse_categorical_accuracy: 0.9930
# Epoch 2/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0299 - sparse_categorical_accuracy: 0.9940
# Epoch 3/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0325 - sparse_categorical_accuracy: 0.9938
# Epoch 4/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0323 - sparse_categorical_accuracy: 0.9939
# Epoch 5/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0304 - sparse_categorical_accuracy: 0.9939
# Epoch 6/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0281 - sparse_categorical_accuracy: 0.9945
# Epoch 7/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0340 - sparse_categorical_accuracy: 0.9940
# Epoch 8/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0301 - sparse_categorical_accuracy: 0.9945
# Epoch 9/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0362 - sparse_categorical_accuracy: 0.9935
# Epoch 10/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0304 - sparse_categorical_accuracy: 0.9948
# 188/188 [==============================] - 0s 2ms/step - loss: 0.0849 - sparse_categorical_accuracy: 0.9902
# Fold 6
# Epoch 1/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9922 - student_loss: 0.0411 - distillation_loss: 9.8342e-04
# Epoch 2/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9924 - student_loss: 0.0350 - distillation_loss: 9.3404e-04
# Epoch 3/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9937 - student_loss: 0.0297 - distillation_loss: 8.3340e-04
# Epoch 4/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9937 - student_loss: 0.0281 - distillation_loss: 8.2879e-04
# Epoch 5/10
# 1688/1688 [==============================] - 7s 4ms/step - sparse_categorical_accuracy: 0.9933 - student_loss: 0.0335 - distillation_loss: 8.8238e-04
# Epoch 6/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9934 - student_loss: 0.0329 - distillation_loss: 8.9265e-04
# Epoch 7/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9928 - student_loss: 0.0383 - distillation_loss: 8.9518e-04
# Epoch 8/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9938 - student_loss: 0.0301 - distillation_loss: 8.3973e-04
# Epoch 9/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9930 - student_loss: 0.0366 - distillation_loss: 9.2158e-04
# Epoch 10/10
# 1688/1688 [==============================] - 7s 4ms/step - sparse_categorical_accuracy: 0.9933 - student_loss: 0.0374 - distillation_loss: 8.7620e-04
# 188/188 [==============================] - 0s 2ms/step - sparse_categorical_accuracy: 0.9905 - student_loss: 0.0719
# Epoch 1/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0408 - sparse_categorical_accuracy: 0.9937
# Epoch 2/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0314 - sparse_categorical_accuracy: 0.9948
# Epoch 3/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0347 - sparse_categorical_accuracy: 0.9943
# Epoch 4/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0349 - sparse_categorical_accuracy: 0.9949
# Epoch 5/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0336 - sparse_categorical_accuracy: 0.9947
# Epoch 6/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0346 - sparse_categorical_accuracy: 0.9944
# Epoch 7/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0320 - sparse_categorical_accuracy: 0.9952
# Epoch 8/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0298 - sparse_categorical_accuracy: 0.9954
# Epoch 9/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0396 - sparse_categorical_accuracy: 0.9946
# Epoch 10/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0266 - sparse_categorical_accuracy: 0.9959
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1504 - sparse_categorical_accuracy: 0.9863
# Fold 7
# Epoch 1/10
# 1688/1688 [==============================] - 7s 4ms/step - sparse_categorical_accuracy: 0.9932 - student_loss: 0.0395 - distillation_loss: 8.5715e-04
# Epoch 2/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9931 - student_loss: 0.0394 - distillation_loss: 9.0478e-04
# Epoch 3/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9941 - student_loss: 0.0276 - distillation_loss: 8.1776e-04
# Epoch 4/10
# 1688/1688 [==============================] - 7s 4ms/step - sparse_categorical_accuracy: 0.9932 - student_loss: 0.0359 - distillation_loss: 8.9926e-04
# Epoch 5/10
# 1688/1688 [==============================] - 7s 4ms/step - sparse_categorical_accuracy: 0.9940 - student_loss: 0.0337 - distillation_loss: 8.4917e-04
# Epoch 6/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9937 - student_loss: 0.0330 - distillation_loss: 8.6205e-04
# Epoch 7/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9936 - student_loss: 0.0353 - distillation_loss: 8.5768e-04
# Epoch 8/10
# 1688/1688 [==============================] - 7s 4ms/step - sparse_categorical_accuracy: 0.9934 - student_loss: 0.0370 - distillation_loss: 9.0132e-04
# Epoch 9/10
# 1688/1688 [==============================] - 7s 4ms/step - sparse_categorical_accuracy: 0.9944 - student_loss: 0.0280 - distillation_loss: 8.1072e-04
# Epoch 10/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9943 - student_loss: 0.0291 - distillation_loss: 8.2196e-04
# 188/188 [==============================] - 0s 2ms/step - sparse_categorical_accuracy: 0.9880 - student_loss: 0.0930
# Epoch 1/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0414 - sparse_categorical_accuracy: 0.9948
# Epoch 2/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0410 - sparse_categorical_accuracy: 0.9947
# Epoch 3/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0314 - sparse_categorical_accuracy: 0.9956
# Epoch 4/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0302 - sparse_categorical_accuracy: 0.9957
# Epoch 5/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0278 - sparse_categorical_accuracy: 0.9961
# Epoch 6/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0408 - sparse_categorical_accuracy: 0.9948
# Epoch 7/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0325 - sparse_categorical_accuracy: 0.9953
# Epoch 8/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0379 - sparse_categorical_accuracy: 0.9953
# Epoch 9/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0303 - sparse_categorical_accuracy: 0.9958
# Epoch 10/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0323 - sparse_categorical_accuracy: 0.9958
# 188/188 [==============================] - 0s 2ms/step - loss: 0.0952 - sparse_categorical_accuracy: 0.9907
# Fold 8
# Epoch 1/10
# 1688/1688 [==============================] - 7s 4ms/step - sparse_categorical_accuracy: 0.9929 - student_loss: 0.0440 - distillation_loss: 9.2353e-04
# Epoch 2/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9940 - student_loss: 0.0362 - distillation_loss: 8.2735e-04
# Epoch 3/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9936 - student_loss: 0.0401 - distillation_loss: 8.2978e-04
# Epoch 4/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9938 - student_loss: 0.0365 - distillation_loss: 8.5147e-04
# Epoch 5/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9945 - student_loss: 0.0315 - distillation_loss: 7.9759e-04
# Epoch 6/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9950 - student_loss: 0.0291 - distillation_loss: 7.4419e-04
# Epoch 7/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9944 - student_loss: 0.0334 - distillation_loss: 8.0657e-04
# Epoch 8/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9947 - student_loss: 0.0345 - distillation_loss: 7.8109e-04
# Epoch 9/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9946 - student_loss: 0.0314 - distillation_loss: 7.9999e-04
# Epoch 10/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9944 - student_loss: 0.0350 - distillation_loss: 8.0385e-04
# 188/188 [==============================] - 0s 2ms/step - sparse_categorical_accuracy: 0.9928 - student_loss: 0.0385
# Epoch 1/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0473 - sparse_categorical_accuracy: 0.9951
# Epoch 2/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0365 - sparse_categorical_accuracy: 0.9953
# Epoch 3/10
# 1688/1688 [==============================] - 4s 3ms/step - loss: 0.0358 - sparse_categorical_accuracy: 0.9956
# Epoch 4/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0296 - sparse_categorical_accuracy: 0.9960
# Epoch 5/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0364 - sparse_categorical_accuracy: 0.9953
# Epoch 6/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0356 - sparse_categorical_accuracy: 0.9961
# Epoch 7/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0350 - sparse_categorical_accuracy: 0.9961
# Epoch 8/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0361 - sparse_categorical_accuracy: 0.9956
# Epoch 9/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0334 - sparse_categorical_accuracy: 0.9961
# Epoch 10/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0387 - sparse_categorical_accuracy: 0.9954
# 188/188 [==============================] - 0s 2ms/step - loss: 0.0779 - sparse_categorical_accuracy: 0.9935
# Fold 9
# Epoch 1/10
# 1688/1688 [==============================] - 7s 4ms/step - sparse_categorical_accuracy: 0.9943 - student_loss: 0.0406 - distillation_loss: 8.2869e-04
# Epoch 2/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9945 - student_loss: 0.0312 - distillation_loss: 8.1058e-04
# Epoch 3/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9938 - student_loss: 0.0394 - distillation_loss: 8.6875e-04
# Epoch 4/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9946 - student_loss: 0.0349 - distillation_loss: 8.0794e-04
# Epoch 5/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9947 - student_loss: 0.0326 - distillation_loss: 7.9892e-04
# Epoch 6/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9947 - student_loss: 0.0287 - distillation_loss: 7.9066e-04
# Epoch 7/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9938 - student_loss: 0.0420 - distillation_loss: 8.7716e-04
# Epoch 8/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9949 - student_loss: 0.0361 - distillation_loss: 7.9727e-04
# Epoch 9/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9957 - student_loss: 0.0246 - distillation_loss: 7.2425e-04
# Epoch 10/10
# 1688/1688 [==============================] - 6s 4ms/step - sparse_categorical_accuracy: 0.9947 - student_loss: 0.0361 - distillation_loss: 7.9410e-04
# 188/188 [==============================] - 0s 2ms/step - sparse_categorical_accuracy: 0.9917 - student_loss: 0.0716
# Epoch 1/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0419 - sparse_categorical_accuracy: 0.9955
# Epoch 2/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0272 - sparse_categorical_accuracy: 0.9964
# Epoch 3/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0388 - sparse_categorical_accuracy: 0.9958
# Epoch 4/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0376 - sparse_categorical_accuracy: 0.9960
# Epoch 5/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0326 - sparse_categorical_accuracy: 0.9964
# Epoch 6/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0316 - sparse_categorical_accuracy: 0.9969
# Epoch 7/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0346 - sparse_categorical_accuracy: 0.9965
# Epoch 8/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0386 - sparse_categorical_accuracy: 0.9959
# Epoch 9/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0423 - sparse_categorical_accuracy: 0.9965
# Epoch 10/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0288 - sparse_categorical_accuracy: 0.9966
# 188/188 [==============================] - 0s 2ms/step - loss: 0.0185 - sparse_categorical_accuracy: 0.9972
# 313/313 [==============================] - 1s 2ms/step - sparse_categorical_accuracy: 0.9726 - student_loss: 0.6141
# 313/313 [==============================] - 1s 2ms/step - loss: 0.7007 - sparse_categorical_accuracy: 0.9772

# %%
fig, axs = plt.subplots(2, 1, figsize=(15,15))

# Traning and validation results
axs[0].plot(np.mean(train_results_with_distillation, 1), '-D') 
axs[0].plot(np.mean(train_results_without_distillation, 1), '-x') 
axs[0].title.set_text('Training Accuracy with and without distillation') 
axs[0].legend(['With Distillation', 'Without Distillation'])  

# Test results
axs[1].plot(val_results_with_distillation, '-D') 
axs[1].plot(val_results_without_distillation, '-x') 
axs[1].title.set_text('Validation Accuracy with and without distillation') 
axs[1].legend(['With Distillation', 'Without Distillation'])

# %%
print(f"Test accuracy with disstillation {test_results_with_distillation['sparse_categorical_accuracy']}")
print(f"Test accuracy without disstillation {test_results_without_distillation['sparse_categorical_accuracy']}")
# Out:
# Test accuracy with disstillation 0.972599983215332
# Test accuracy without disstillation 0.9771999716758728

# %%
# # Save the model to load in future
# %mkdir -p Exp1Models

# studnet_model.save('Exp1Models/studnet_model')
# studnet_model_without_distillation.save('Exp1Models/studnet_model_without_distillation')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Exp1Models/studnet_model\assets
# INFO:tensorflow:Assets written to: Exp1Models/studnet_model\assets
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Exp1Models/studnet_model_without_distillation\assets
# INFO:tensorflow:Assets written to: Exp1Models/studnet_model_without_distillation\assets
